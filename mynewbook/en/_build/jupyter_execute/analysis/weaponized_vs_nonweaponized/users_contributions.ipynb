# %% [markdown]
# # User Contributions Analysis
#
# This notebook focuses on retrieving, analysing, and visualising **user contribution behaviour on the English Wikipedia**. The dataframe ```user_contribs.csv```is containing the contributions for the 20 (10 registered and 10 IP address users) most active contributors of the small database.
#
# User contributions are retrieved using the **Wikimedia API**, via the `action=query` endpoint with `list=usercontribs`.
# For each edit, a rich set of metadata is collected using  ```ucprop="ids|title|timestamp|comment|sizediff|flags|tags|orescores```. The exact Wikipedia API function used to create the dataframe can be seen ...
#
# This metadata allows us to study not only *what* users edit, but *how*, *in which context*, and *how these edits are institutionally evaluated*.
#
# ---
#
# ## Retrieved Parameters and Their Meaning
#
# - **`ids`**
#   Numerical identifiers for the user, the page, the revision, and its parent revision.
#   These IDs allow unambiguous tracking of edits and their relationships.
#
# - **`ns` (Namespace)**
#
#   Numerical identifiers that tells in which area of Wikipedia the user has made its edit. The most common is the **0** and it     stands for the main wikipedia page. The **1** is for the talk page of the article, etc... The full list is displayed in the     corresponding section further in the notebook.
#
# - **`title`**
#   Title of the edited page.
#   In this project, it is used to identify **which articles or thematic areas** users tend to edit.
#
# - **`timestamp`**
#   Date and time of the edit.
#   This enables temporal analyses, such as activity patterns over time or around geopolitical events.
#
# - **`comment`**
#   Edit summary provided by the user.
#   Comments are analysed to study **editorial justification, transparency, and coordination practices**.
#
# - **`sizediff`**
#   The net number of bytes added or removed by the edit.
#   This is a key variable to compare **editing intensity** across user types (registered vs anonymous) and across contexts such as weaponised vs non-weaponised articles.
#
# - **`flags`**
#   Boolean indicators describing special properties of the edit, such as:
#   - `minor` (small or routine edit),
#   - `bot` (automated edit),
#   - `new` (page creation).
#
#   These flags help distinguish between **maintenance work, automation, and substantive editorial interventions**.
#
# - **`tags`**
#   Labels automatically attached to edits, describing both **editing context** and **post-publication outcomes**.
#   They include:
#   - Editing context: `mobile edit`, `visualeditor`
#   - Reverts & conflict: `mw-undo`, `mw-reverted`, `rollback`, `manual-revert`
#   - Anti-vandalism tools: `huggle`, `twinkle`, `fast revert`, `anti-vandal`
#
#   Tags are crucial to identify **editorial conflict, surveillance, and enforcement mechanisms**.
#
# - **`orescores`**
#   Scores produced by **ORES (Objective Revision Evaluation Service)**, Wikipedia’s machine-learning system for edit quality assessment.
#   It assigns probabilities that an edit is:
#   - damaging
#   - made in good faith
#
#   ORES scores are treated here as indicators of **institutional suspicion and control**, rather than ground truth.
#
# ---
#
# ## Scope of the Notebook
#
# This notebook contains:
#
# - Reusable functions to retrieve and preprocess user contributions from Wikipedia
# - Exploratory visualisations to identify behavioural patterns
# - Statistical and descriptive analyses to understand how user metadata relates to editing behaviour
#
# ---
#
# ## Research Objective
#
# The final goal of this notebook is to **identify features and behavioural signals associated with weaponisation patterns** in Wikipedia editing activity.
# These features are intended to be:
# - empirically grounded,
# - interpretable,
# - and reusable as inputs for the development of a downstream **Large Language Model (LLM)** aimed at analysing or detecting coordinated or manipulative editorial behaviour.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import calendar
from datetime import timedelta
from scipy.stats import variation
from tqdm import tqdm

# %%
# import our small preprocessed database and the users contributions
df = pd.read_csv('../../datas/final/small_db_preprocess.csv')
df_contrib = pd.read_csv('../../datas/interim/Small Database Analysis/users_contribs.csv')

# %%
df_contrib
# Out:
#           userid           user    pageid       revid    parentid  ns  \
# 0       38910429           LSGH  63260687  1075136185  1074964872   0
# 1       38910429           LSGH  63339598  1075135994  1074964830  10
# 2       38910429           LSGH  63281706  1075022468  1074969215   0
# 3       38910429           LSGH  63353757  1075022344  1074969128  10
# 4       38910429           LSGH  63262762  1075022265  1074414768   0
# ...          ...            ...       ...         ...         ...  ..
# 679566         0  217.118.81.18  29636778   421978294   419568606   0
# 679567         0  217.118.81.18   2079383   421960113   418496575   0
# 679568         0  217.118.81.18  18577625   383900698   382635178   0
# 679569         0  217.118.81.18    154309   383900443   383896136   0
# 679570         0  217.118.81.18    154309   383896136   383299760   0
#
#                                                     title  \
# 0                            COVID-19 pandemic in Bahrain
# 1       Template:COVID-19 pandemic data/South Africa m...
# 2                             COVID-19 pandemic in Latvia
# 3       Template:COVID-19 pandemic data/Latvia medical...
# 4                            COVID-19 pandemic in Andorra
# ...                                                   ...
# 679566                                       2011 Ykkönen
# 679567                                           FC Honka
# 679568                           Culture Club discography
# 679569                                       Culture Club
# 679570                                       Culture Club
#
#                    timestamp                              comment  sizediff  \
# 0       2022-03-04T04:03:16Z  Updating number of cases in infobox         0
# 1       2022-03-04T04:01:40Z  Adding number of cases for March 03        33
# 2       2022-03-03T13:19:02Z  Updating number of cases in infobox         0
# 3       2022-03-03T13:18:11Z  Adding number of cases for March 03        30
# 4       2022-03-03T13:17:26Z  Updating number of cases in infobox         0
# ...                      ...                                  ...       ...
# 679566  2011-04-02T13:51:57Z                       /* Overview */         0
# 679567  2011-04-02T10:41:15Z                  /* Current squad */       118
# 679568  2010-09-09T20:38:22Z                  /* Studio albums */       -15
# 679569  2010-09-09T20:36:54Z                    /* Discography */         0
# 679570  2010-09-09T20:09:42Z                    /* Discography */        -2
#
#                   tags oresscores       username  top  new  texthidden  \
# 0       ['wikieditor']         []           LSGH  NaN  NaN         NaN
# 1       ['wikieditor']         []           LSGH  NaN  NaN         NaN
# 2       ['wikieditor']         []           LSGH  NaN  NaN         NaN
# 3       ['wikieditor']         []           LSGH  NaN  NaN         NaN
# 4       ['wikieditor']         []           LSGH  NaN  NaN         NaN
# ...                ...        ...            ...  ...  ...         ...
# 679566              []         []  217.118.81.18  NaN  NaN         NaN
# 679567              []         []  217.118.81.18  NaN  NaN         NaN
# 679568              []         []  217.118.81.18  NaN  NaN         NaN
# 679569              []         []  217.118.81.18  NaN  NaN         NaN
# 679570              []         []  217.118.81.18  NaN  NaN         NaN
#
#         suppressed  minor  commenthidden
# 0              NaN    NaN            NaN
# 1              NaN    NaN            NaN
# 2              NaN    NaN            NaN
# 3              NaN    NaN            NaN
# 4              NaN    NaN            NaN
# ...            ...    ...            ...
# 679566         NaN    NaN            NaN
# 679567         NaN    NaN            NaN
# 679568         NaN    NaN            NaN
# 679569         NaN    NaN            NaN
# 679570         NaN    NaN            NaN
#
# [679571 rows x 19 columns]

# %% [markdown]
# ## Overviewing and Cleaning the dataset

# %%
df_metadata = {
    # Users
    "number_of_unique_users": df_contrib["user"].nunique(),

    # Pages / revisions
    "number_of_unique_pages_edited": df_contrib["title"].nunique(),
    "number_of_unique_revisions": df_contrib["revid"].nunique(),

    # Namespaces
    "number_of_namespaces": df_contrib["ns"].nunique(),

    # Temporal coverage
    "first_edit_timestamp": df_contrib["timestamp"].min(),
    "last_edit_timestamp": df_contrib["timestamp"].max(),

    # Edit characteristics
    "total_number_of_edits": len(df_contrib),
    "median_edit_size_diff": df_contrib["sizediff"].median(),
    "mean_edit_size_diff": df_contrib["sizediff"].mean(),

    # Comments
    "proportion_missing_comments": df_contrib["comment"].isna().mean(),
    "number_hidden_comments": df_contrib["commenthidden"].nunique(),

    # Editorial outcomes
    "number_top_revisions": df_contrib["top"].nunique(),
    "number_new_pages": df_contrib["new"].nunique(),
    "number_minor_edits": df_contrib["minor"].nunique(),

    # Moderation / visibility
    "number_of_text_hidden_edits": df_contrib["texthidden"].nunique(),
    "number_of_suppressed_edits": df_contrib["suppressed"].nunique(),

    # Tags / evaluation
    "proportion_edits_with_tags": df_contrib["tags"].notna().mean(),
    "number_edits_with_orescores": df_contrib["oresscores"].nunique()
}

df_metadata
# Out:
# {'number_of_unique_users': 20,
#  'number_of_unique_pages_edited': 119245,
#  'number_of_unique_revisions': 679571,
#  'number_of_namespaces': 23,
#  'first_edit_timestamp': '2004-06-03T04:10:48Z',
#  'last_edit_timestamp': '2026-01-06T12:08:37Z',
#  'total_number_of_edits': 679571,
#  'median_edit_size_diff': 31.0,
#  'mean_edit_size_diff': 151.58474243309382,
#  'proportion_missing_comments': 0.16934507211167046,
#  'number_hidden_comments': 0,
#  'number_top_revisions': 0,
#  'number_new_pages': 0,
#  'number_minor_edits': 0,
#  'number_of_text_hidden_edits': 0,
#  'number_of_suppressed_edits': 0,
#  'proportion_edits_with_tags': 1.0,
#  'number_edits_with_orescores': 928}

# %%
def clean(dataframe):
    
    df = dataframe.copy()
    # easy way to detected IP address
    ipv4_ipv6_pattern = (
        r"^(?:\d{1,3}\.){3}\d{1,3}$|"  # IPv4
        r"^(?:[A-Fa-f0-9]{0,4}:){2,7}[A-Fa-f0-9]{0,4}$"  # IPv6
    )
    
    # find what type of user a name is
    df["is_anon"] = df["user"].str.contains(ipv4_ipv6_pattern, na=False)
    df['is_bot'] = df['user'].str.contains('bot', case=False, na=False)
    
    def get_user_type(row):
        if row["is_anon"]:
            return "Anonymous (IP)"
        elif row["is_bot"]:
            return "Bot"
        else:
            return "Registered"        
    
    df['user_type'] = df.apply(get_user_type, axis=1)
    df = df.drop(['userid', 'revid', 'parentid', 'username', 
                                 'is_bot', 'is_anon', 'top', 'new', 'minor',
                                 'commenthidden', 'texthidden', 'suppressed'], axis=1)

    return df

# %%
df_contrib_clean = clean(df_contrib)
df_contrib_clean
# Out:
#                  user    pageid  ns  \
# 0                LSGH  63260687   0
# 1                LSGH  63339598  10
# 2                LSGH  63281706   0
# 3                LSGH  63353757  10
# 4                LSGH  63262762   0
# ...               ...       ...  ..
# 679566  217.118.81.18  29636778   0
# 679567  217.118.81.18   2079383   0
# 679568  217.118.81.18  18577625   0
# 679569  217.118.81.18    154309   0
# 679570  217.118.81.18    154309   0
#
#                                                     title  \
# 0                            COVID-19 pandemic in Bahrain
# 1       Template:COVID-19 pandemic data/South Africa m...
# 2                             COVID-19 pandemic in Latvia
# 3       Template:COVID-19 pandemic data/Latvia medical...
# 4                            COVID-19 pandemic in Andorra
# ...                                                   ...
# 679566                                       2011 Ykkönen
# 679567                                           FC Honka
# 679568                           Culture Club discography
# 679569                                       Culture Club
# 679570                                       Culture Club
#
#                    timestamp                              comment  sizediff  \
# 0       2022-03-04T04:03:16Z  Updating number of cases in infobox         0
# 1       2022-03-04T04:01:40Z  Adding number of cases for March 03        33
# 2       2022-03-03T13:19:02Z  Updating number of cases in infobox         0
# 3       2022-03-03T13:18:11Z  Adding number of cases for March 03        30
# 4       2022-03-03T13:17:26Z  Updating number of cases in infobox         0
# ...                      ...                                  ...       ...
# 679566  2011-04-02T13:51:57Z                       /* Overview */         0
# 679567  2011-04-02T10:41:15Z                  /* Current squad */       118
# 679568  2010-09-09T20:38:22Z                  /* Studio albums */       -15
# 679569  2010-09-09T20:36:54Z                    /* Discography */         0
# 679570  2010-09-09T20:09:42Z                    /* Discography */        -2
#
#                   tags oresscores       user_type
# 0       ['wikieditor']         []      Registered
# 1       ['wikieditor']         []      Registered
# 2       ['wikieditor']         []      Registered
# 3       ['wikieditor']         []      Registered
# 4       ['wikieditor']         []      Registered
# ...                ...        ...             ...
# 679566              []         []  Anonymous (IP)
# 679567              []         []  Anonymous (IP)
# 679568              []         []  Anonymous (IP)
# 679569              []         []  Anonymous (IP)
# 679570              []         []  Anonymous (IP)
#
# [679571 rows x 10 columns]

# %% [markdown]
# ## Ukraine Russia related articles

# %%
# Top 10 users
top_users = (
    df[df["comment"].notna()]
    .groupby("user")
    .size()
    .sort_values(ascending=False)
    .head(10)
    .index
)
top_users = list(top_users)

df_top = df[df["user"].isin(top_users)]

# Count edits per (user, year, weaponised)
grouped = (
    df_top.groupby(["user", "year", "weaponised"])
    .size()
    .reset_index(name="count")
)


custom_palette = {
    "Weaponised": "#ed2939",
    "Not Weaponised": "forestgreen"
}

sns.set_style("whitegrid")

grouped["year"] = grouped["year"].astype(str)


g = sns.catplot(
    data=grouped,
    kind="bar",
    x="year",
    y="count",
    hue="weaponised",
    col="user",
    col_wrap=2,
    height=4,
    aspect=1.5,
    palette=custom_palette,
    sharey=False,
    sharex=False
)

# Titles and labels
g.set_titles("{col_name}")
g.set_axis_labels("Year", "Number of Edits")
g.fig.suptitle(
    "Weaponised vs Non-Weaponised Edits per Year (Top 10 Users)",
    fontsize=16
)

# Per-axis adjustments
for ax in g.axes.flat:
    # Keep only years with data (already handled by seaborn)
    ax.tick_params(axis="x", rotation=0)

    # Dynamic Y-axis per user
    heights = [bar.get_height() for bar in ax.patches]
    if heights:
        ax.set_ylim(0, max(heights) * 1.15)

g.tight_layout()
plt.subplots_adjust(top=0.9)
wanna_save = True
if wanna_save:
    plt.savefig(
        f"../../plots/Small Database Analysis/Weaponised vs Non-Weaponised Edits per Year (Top 10 Registered Users).png",
        dpi=300,
        bbox_inches="tight"
    )
plt.show()
# Out:
# /Users/garambois/miniforge3/envs/ada/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Top 10 IP users (Anonymous)
top_ip_users = (
    df[(df["comment"].notna()) & (df["user_type"] == "Anonymous (IP)")]
    .groupby("user")
    .size()
    .sort_values(ascending=False)
    .head(10)
    .index
)
top_ip_users = list(top_ip_users)

df_ip_top = df[df["user"].isin(top_ip_users)]

# Count edits per (user, year, weaponised)
grouped_ip = (
    df_ip_top
    .groupby(["user", "year", "weaponised"])
    .size()
    .reset_index(name="count")
)

custom_palette = {
    "Weaponised": "#ed2939",
    "Not Weaponised": "forestgreen"
}

sns.set_style("whitegrid")

grouped_ip["year"] = grouped_ip["year"].astype(str)

g = sns.catplot(
    data=grouped_ip,
    kind="bar",
    x="year",
    y="count",
    hue="weaponised",
    col="user",
    col_wrap=2,
    height=4,
    aspect=1.5,
    palette=custom_palette,
    sharey=False,
    sharex=False
)

g.set_titles("{col_name}")
g.set_axis_labels("Year", "Number of Edits")
g.fig.suptitle(
    "Weaponised vs Non-Weaponised Edits per Year (Top 10 IP Users)",
    fontsize=16
)

for ax in g.axes.flat:

    ax.tick_params(axis="x", rotation=0)
    heights = [bar.get_height() for bar in ax.patches]
    if heights:
        ax.set_ylim(0, max(heights) * 1.15)

g.tight_layout()
plt.subplots_adjust(top=0.9)
wanna_save = True
if wanna_save:
    plt.savefig(
        f"../../plots/Small Database Analysis/Weaponised vs Non-Weaponised Edits per Year (Top 10 IP Users).png",
        dpi=300,
        bbox_inches="tight"
    )
plt.show()
# Out:
# /Users/garambois/miniforge3/envs/ada/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# we want to keep only the contributions in the main namespace ( =0 ) of wikipedia
df_articles = df_contrib_clean[df_contrib_clean["ns"] == 0].copy()

# Also possible to use the ukraine keyword large, available in the Annex of the report
ukraine_keywords_small = [
    "ukraine", "ukrainian", "kyiv", "kiev", "crimea", "crimean", "kuban",
    "donbas", "donetsk", "luhansk",
    "maidan", "yanukovych", "yushchenko", "zelenskyy", "poroshenko",
    "catherine", "bukovina", "bessarabia", "eastern",
    "euromaidan", "dnipro", "odessa", "sevastopol", "putin", "rus'",
    "russia", "russian", "moscow", "kremlin", "soviet"
]

# function that allow us to detect if the article is uk or ru related thanks to keywords
def is_ukraine_russia_related(title, keywords):
    if pd.isna(title):
        return False
    title = title.lower()
    return any(kw in title for kw in keywords)

# change the key words list to get for the big set.
df_articles["ua_ru_related"] = df_articles["title"].apply(
    lambda x: is_ukraine_russia_related(x, ukraine_keywords_small)
)


# PLEASE CHANGE HERE Registered by "Anonymous (IP)" TO GET FOR IP USERS
df_reg = df_articles[df_articles["user_type"] == "Registered"].copy()

top_registered = (
    df_reg.groupby("user")
    .size()
    .sort_values(ascending=False)
    .head(10)
    .index
)

stats = (
    df_reg[df_reg["user"].isin(top_registered)]
    .groupby(["user", "ua_ru_related"])
    .size()
    .reset_index(name="count")
)

stats["total"] = stats.groupby("user")["count"].transform("sum")
stats["proportion"] = stats["count"] / stats["total"]

stats["category"] = stats["ua_ru_related"].map({
    True: "Ukraine–Russia related",
    False: "Other articles"
})

sns.set_style("whitegrid")

custom_palette = {
    "Ukraine–Russia related": "#f5c518",  
    "Other articles": "silver"            
}

plt.figure(figsize=(11, 6))

sns.barplot(
    data=stats,
    x="user",
    y="proportion",
    hue="category",
    palette=custom_palette
)

plt.ylabel("Proportion of edits")
plt.xlabel("Registered users")
plt.title(
    "Proportion of Ukraine–Russia–Related vs Other Edits\n"
    "Top 10 Registered Users (Small Keyword Set)"
)

plt.ylim(0, 1)
plt.legend(title="Article category", loc="upper right")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Size diff

# %%
df_contrib_clean.groupby("user_type")["sizediff"].agg(
    count="count",
    median="median",
    mean="mean"
)
# Out:
#                  count  median        mean
# user_type
# Anonymous (IP)    2317    16.0   97.688822
# Registered      677254    31.0  151.769129

# %% [markdown]
# ## User activity & Burstiness

# %%
def preprocess_usercontribs(df):
    """
    Ensures timestamp column is a proper datetime and sorts values.
    """
    df = df.copy()
    df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")
    return df.sort_values(["user", "timestamp"])

def compute_edit_frequency(df):
    """
    Computes edit frequency metrics for each user:
    - total edits
    - active days
    - edits per day
    - edits per month
    - edits per active day (engagement intensity)
    
    Returns a DataFrame indexed by username.
    """
    df = preprocess_usercontribs(df)
    
    freq = (
        df.groupby("user")
          .agg(
              total_edits=("user", "size"),
              first_edit=("timestamp", "min"),
              last_edit=("timestamp", "max")
          )
    )
    # Convert to metrics
    freq["active_days"] = (freq["last_edit"] - freq["first_edit"]).dt.days + 1
    freq["active_months"] = freq["active_days"] / 30.44  # precise month equivalence
    freq["edits_per_day"] = freq["total_edits"] / freq["active_days"]
    freq["edits_per_month"] = freq["total_edits"] / (freq["active_days"] / 30)
    freq["edits_per_active_day"] = freq["total_edits"] / freq["active_days"]
        
    return freq

def compute_burstiness_for_user(timestamps):
    """
    Computes burstiness B for a single user:
    
         B = (σ - μ) / (σ + μ)
    
    where μ = mean inter-event time, σ = std dev of inter-event time.
    
    Range:
    - B → -1 : perfectly regular
    - B = 0  : Poisson-like random
    - B → 1  : very bursty
    
    Returns None if insufficient data.
    """
    if len(timestamps) < 3: # means we have insufficient data
        return None
    
    deltas = np.diff(timestamps.astype("int64") // 1e9)  # seconds
    
    mu = deltas.mean()
    sigma = deltas.std()
    
    if (mu + sigma) == 0:
        return None
    return (sigma - mu) / (sigma + mu)

def compute_burstiness(df):
    """
    Computes burstiness for each user.
    Returns a DataFrame: username, burstiness.
    """
    df = preprocess_usercontribs(df)

    burstiness_list = []
    for user, group in df.groupby("user"):
        timestamps = group["timestamp"].values
        B = compute_burstiness_for_user(timestamps)
        burstiness_list.append({"user": user, "burstiness": B})
    
    return pd.DataFrame(burstiness_list)

def compute_temporal_patterns(df):
    """
    Extracts temporal patterns for each user:
    - most_active_hour
    - most_active_weekday
    - night_edit_ratio (edits 00:00–06:00)
    - weekend_edit_ratio
    
    Returns DataFrame: one row per user.
    """
    df = preprocess_usercontribs(df)

    df["hour"] = df["timestamp"].dt.hour
    df["weekday"] = df["timestamp"].dt.weekday  # 0=Monday
    df["is_weekend"] = df["weekday"] >= 5

    results = (
        df.groupby("user")
          .agg(
              most_active_hour=("hour", lambda x: x.value_counts().idxmax()),
              most_active_weekday=("weekday", lambda x: x.value_counts().idxmax()),
              weekend_edit_ratio=("is_weekend", "mean")
          )
    )
    
    return results

def compute_user_activity_profile(df):
    """
    Combines all activity-related metrics into a single profiling table:
    - edit frequency
    - burstiness
    - temporal patterns
    """
    freq = compute_edit_frequency(df)
    burst = compute_burstiness(df)
    patterns = compute_temporal_patterns(df)

    full = (
        freq
        .merge(burst, on="user", how="left")
        .merge(patterns, on="user", how="left")
    )

    return full

def burst_heatmap(dataframe, normalization="max", show_user_labels=True):
    """
    Parameters
    ----------
    normalization : {"max", "log"}
        - "max": normalize each user by their max monthly activity (default)
        - "log": apply log1p to raw activity (keeps volume information)
        
    show_user_labels : bool
        Whether to display user labels on the y-axis
    """
    df = dataframe.copy()

    df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")
    df = df.dropna(subset=["timestamp"])
    
    # we want to create a new column that converts the date to a month and a year
    df["year_month"] = df["timestamp"].dt.to_period("M")

    activity = (
        df.groupby(["user", "year_month"])
          .size()
          .unstack(fill_value=0)
    )

    # normalisation 
    if normalization == "max":
        activity_proc = activity.div(activity.max(axis=1), axis=0)
        cbar_label = "Normalized monthly activity (per user)"

    # allow to see more volume. Registered users will be very bright and IP users very dark
    elif normalization == "log":
        activity_proc = np.log1p(activity)
        cbar_label = "Log-scaled monthly activity"
        
    else:
        raise ValueError("normalization must be 'max' or 'log'")

    # burstiness ordering from most bursty to less 
    burst = compute_burstiness(df).set_index("user")

    activity_proc = activity_proc.loc[
        activity_proc.index.intersection(burst.index)
    ]

    activity_proc = activity_proc.loc[
        burst["burstiness"].sort_values(ascending=False).index
    ]

    # plot using seaborn 
    plt.figure(figsize=(16, max(6, 0.35 * len(activity_proc))))

    sns.heatmap(
        activity_proc,
        cmap="magma",
        cbar_kws={"label": cbar_label},
        xticklabels=12,
        yticklabels=show_user_labels
    )
    
    plt.title("Monthly Editing Activity per User (sorted by burstiness)")
    plt.xlabel("Time (Year–Month)")
    plt.ylabel("Users")
    plt.tight_layout()
    plt.show()

# %%
df_activity = compute_user_activity_profile(df_contrib_clean)
df_activity
# Out:
#                    user  total_edits                first_edit  \
# 0          124.190.40.8          121 2009-07-31 02:33:19+00:00
# 1       172.202.173.230           14 2005-07-15 12:59:46+00:00
# 2         174.3.111.148          649 2009-10-15 21:42:47+00:00
# 3        212.137.36.230         1106 2011-04-15 11:46:40+00:00
# 4         217.118.81.18           45 2010-09-09 20:09:42+00:00
# 5         217.118.81.21           33 2010-03-21 06:34:31+00:00
# 6         24.183.100.38           13 2007-01-23 17:52:45+00:00
# 7         61.102.45.248           10 2006-12-07 11:13:15+00:00
# 8         77.252.47.155           26 2020-03-19 20:59:55+00:00
# 9        94.178.235.125          300 2020-03-21 10:02:33+00:00
# 10  Aleksandr Grigoryev       159302 2006-10-08 02:40:55+00:00
# 11            Dbachmann       225111 2004-07-18 08:59:34+00:00
# 12                Irpen        31004 2004-06-03 04:10:48+00:00
# 13                 LSGH        59466 2020-04-03 11:09:13+00:00
# 14               Mzajac        65102 2004-06-08 22:15:05+00:00
# 15              Seryo93         4711 2009-06-06 12:04:49+00:00
# 16      TheDraperyFalls        11164 2011-10-04 07:07:50+00:00
# 17               Toddy1        51972 2007-01-01 12:57:45+00:00
# 18                  UP9          391 2009-05-26 11:16:36+00:00
# 19         Yulia Romero        69031 2006-01-21 22:40:45+00:00
#
#                    last_edit  active_days  active_months  edits_per_day  \
# 0  2010-02-16 12:13:32+00:00          201       6.603154       0.601990
# 1  2005-07-15 16:01:39+00:00            1       0.032852      14.000000
# 2  2009-11-16 07:04:18+00:00           32       1.051248      20.281250
# 3  2019-05-14 15:30:28+00:00         2952      96.977661       0.374661
# 4  2018-05-22 16:17:28+00:00         2812      92.378449       0.016003
# 5  2018-05-17 11:43:08+00:00         2980      97.897503       0.011074
# 6  2007-02-25 08:13:12+00:00           33       1.084100       0.393939
# 7  2006-12-09 18:21:24+00:00            3       0.098555       3.333333
# 8  2022-01-13 13:19:27+00:00          665      21.846255       0.039098
# 9  2020-03-25 17:42:19+00:00            5       0.164258      60.000000
# 10 2026-01-01 21:24:17+00:00         7026     230.814717      22.673214
# 11 2023-04-01 09:42:16+00:00         6832     224.441524      32.949502
# 12 2008-11-11 01:59:04+00:00         1622      53.285151      19.114673
# 13 2022-03-04 04:03:16+00:00          700      22.996058      84.951429
# 14 2024-09-16 23:12:55+00:00         7406     243.298292       8.790440
# 15 2025-04-08 16:56:46+00:00         5786     190.078844       0.814207
# 16 2025-11-17 18:21:47+00:00         5159     169.480946       2.163985
# 17 2026-01-05 15:31:28+00:00         6945     228.153745       7.483369
# 18 2022-01-03 14:39:02+00:00         4606     151.314060       0.084889
# 19 2026-01-06 12:08:37+00:00         7290     239.487516       9.469273
#
#     edits_per_month  edits_per_active_day  burstiness  most_active_hour  \
# 0         18.059701              0.601990    0.555471                12
# 1        420.000000             14.000000    0.334758                13
# 2        608.437500             20.281250    0.630330                 0
# 3         11.239837              0.374661    0.931559                13
# 4          0.480085              0.016003    0.309716                13
# 5          0.332215              0.011074    0.186475                11
# 6         11.818182              0.393939    0.381893                22
# 7        100.000000              3.333333    0.440465                18
# 8          1.172932              0.039098    0.653572                13
# 9       1800.000000             60.000000    0.705260                10
# 10       680.196413             22.673214    0.849691                 2
# 11       988.485070             32.949502    0.843615                10
# 12       573.440197             19.114673    0.899897                19
# 13      2548.542857             84.951429    0.709042                 8
# 14       263.713206              8.790440    0.837399                17
# 15        24.426201              0.814207    0.736239                16
# 16        64.919558              2.163985    0.772725                12
# 17       224.501080              7.483369    0.794869                19
# 18         2.546678              0.084889    0.616838                 7
# 19       284.078189              9.469273    0.793112                17
#
#     most_active_weekday  weekend_edit_ratio
# 0                     1            0.272727
# 1                     4            0.000000
# 2                     6            0.460709
# 3                     4            0.016275
# 4                     1            0.333333
# 5                     6            0.393939
# 6                     3            0.076923
# 7                     5            0.900000
# 8                     6            0.692308
# 9                     5            0.756667
# 10                    6            0.296205
# 11                    2            0.212095
# 12                    0            0.237002
# 13                    2            0.288535
# 14                    3            0.226675
# 15                    5            0.329866
# 16                    0            0.234772
# 17                    6            0.339106
# 18                    5            0.335038
# 19                    4            0.173270

# %%
burst_heatmap(df_contrib, normalization="max", show_user_labels=True)
# Out:
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_60508/1141725986.py:144: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["year_month"] = df["timestamp"].dt.to_period("M")

# %% [markdown]
# ## Namespace

# %%
WIKIPEDIA_NAMESPACES = {
    -2: "Media",
    -1: "Special",
     0: "Article",
     1: "Talk",
     2: "User",
     3: "User Talk",
     4: "Wikipedia",
     5: "Wikipedia Talk",
     6: "File",
     7: "File Talk",
     8: "MediaWiki",
     9: "MediaWiki Talk",
    10: "Template",
    11: "Template Talk",
    12: "Help",
    13: "Help Talk",
    14: "Category",
    15: "Category Talk",
    100: "Portal",
    101: "Portal Talk",
    118: "Draft",
    119: "Draft Talk",
    126: "MOS",
    127: "MOS Talk",
    710: "TimedText",
    711: "TimedText Talk",
    828: "Module",
    829: "Module Talk",
    1728: "Event",
    1729: "Event Talk",
    108: "Book",
    109: "Book Talk",
    442: "Course",
    423: "Course Talk",
    444: "Institution",
    445: "Institution Talk",
    446: "Education Program",
    447: "Education Program Talk",
    2300: "Gadget",
    2301: "Gadget Talk",
    2302: "Gadget Definition",
    2303: "Gadget Definition Talk",
    2600: "Topic"
}


def add_namespace_label(df, ns_col="ns"):
    """
    Adds a column 'namespace' to the usercontribs dataframe
    that translates namespace IDs to human-readable names.

    Parameters
    ----------
    df : pd.DataFrame
        User contributions dataframe containing a column with namespace IDs.
    ns_col : str
        Column name storing the namespace ID (default: 'ns').

    Returns
    -------
    pd.DataFrame
        Copy of dataframe with new column 'namespace' (string).
    """

    df = df.copy()

    df["namespace"] = df[ns_col].map(WIKIPEDIA_NAMESPACES).fillna("Unknown namespace")

    return df

def classify_namespace_family(df):
    """
    Adds a 'namespace_family' column grouping content namespaces
    with their corresponding Talk namespaces.

    For example:
    - ns=0 and ns=1 → 'Article'
    - ns=2 and ns=3 → 'User'
    - ns=10 and ns=11 → 'Template'

    Works for all namespaces defined in the global mapping.
    """

    df = df.copy()

    keys_2_del = [-2, -1]
    for key in keys_2_del:
        del WIKIPEDIA_NAMESPACES[key]

    df["namespace_label"] = df["ns"].map(WIKIPEDIA_NAMESPACES)
    df["namespace_family"] = df["namespace_label"].str.replace(" Talk", "")

    return df

def compute_namespace_distribution(df):
    """
    Returns a table showing how many edits a user made in each namespace.

    Output columns:
    - username
    - namespace_family
    - edit_count
    """

    df = classify_namespace_family(df)

    counts = (
        df.groupby(["user", "namespace_family"])
          .size()
          .reset_index(name="edit_count")
    )

    return counts

def compute_user_namespace_profile(df):
    """
    Computes how many edits each user made in each namespace,
    returning a pivoted table (users × namespaces).
    """

    counts = compute_namespace_distribution(df)

    pivot = counts.pivot_table(
        index="user",
        columns="namespace_family",
        values="edit_count",
        fill_value=0
    )

    return pivot

# %%
df_contrib_ns = add_namespace_label(df_contrib)
df_contrib_ns = classify_namespace_family(df_contrib_ns)
df_contrib_ns["namespace_label"].value_counts(normalize=True) * 100
# Out:
# namespace_label
# Article           72.397292
# Talk              10.183483
# Template           6.343119
# User Talk          4.649404
# Wikipedia          2.428150
# Category           1.485055
# User               0.923230
# Wikipedia Talk     0.692937
# Template Talk      0.379651
# Portal             0.250452
# File               0.081081
# Portal Talk        0.034875
# Category Talk      0.033256
# MediaWiki Talk     0.030313
# Module             0.023250
# Draft              0.013979
# File Talk          0.013685
# Help Talk          0.012949
# Help               0.008682
# Module Talk        0.007358
# MediaWiki          0.004562
# Draft Talk         0.001766
# MOS                0.001472
# Name: proportion, dtype: float64

# %%
df_contrib_clean
# Out:
#                  user    pageid  ns  \
# 0                LSGH  63260687   0
# 1                LSGH  63339598  10
# 2                LSGH  63281706   0
# 3                LSGH  63353757  10
# 4                LSGH  63262762   0
# ...               ...       ...  ..
# 679566  217.118.81.18  29636778   0
# 679567  217.118.81.18   2079383   0
# 679568  217.118.81.18  18577625   0
# 679569  217.118.81.18    154309   0
# 679570  217.118.81.18    154309   0
#
#                                                     title  \
# 0                            COVID-19 pandemic in Bahrain
# 1       Template:COVID-19 pandemic data/South Africa m...
# 2                             COVID-19 pandemic in Latvia
# 3       Template:COVID-19 pandemic data/Latvia medical...
# 4                            COVID-19 pandemic in Andorra
# ...                                                   ...
# 679566                                       2011 Ykkönen
# 679567                                           FC Honka
# 679568                           Culture Club discography
# 679569                                       Culture Club
# 679570                                       Culture Club
#
#                    timestamp                              comment  sizediff  \
# 0       2022-03-04T04:03:16Z  Updating number of cases in infobox         0
# 1       2022-03-04T04:01:40Z  Adding number of cases for March 03        33
# 2       2022-03-03T13:19:02Z  Updating number of cases in infobox         0
# 3       2022-03-03T13:18:11Z  Adding number of cases for March 03        30
# 4       2022-03-03T13:17:26Z  Updating number of cases in infobox         0
# ...                      ...                                  ...       ...
# 679566  2011-04-02T13:51:57Z                       /* Overview */         0
# 679567  2011-04-02T10:41:15Z                  /* Current squad */       118
# 679568  2010-09-09T20:38:22Z                  /* Studio albums */       -15
# 679569  2010-09-09T20:36:54Z                    /* Discography */         0
# 679570  2010-09-09T20:09:42Z                    /* Discography */        -2
#
#                   tags oresscores       user_type
# 0       ['wikieditor']         []      Registered
# 1       ['wikieditor']         []      Registered
# 2       ['wikieditor']         []      Registered
# 3       ['wikieditor']         []      Registered
# 4       ['wikieditor']         []      Registered
# ...                ...        ...             ...
# 679566              []         []  Anonymous (IP)
# 679567              []         []  Anonymous (IP)
# 679568              []         []  Anonymous (IP)
# 679569              []         []  Anonymous (IP)
# 679570              []         []  Anonymous (IP)
#
# [679571 rows x 10 columns]

# %% [markdown]
# ## ORES Score

# %%
df_contrib_ores = df_contrib.copy()

def get_ores_model_type(d):
    if "[]" in d:
        return "none"
    if "draftquality" in d:
        return "draftquality"
    if "damaging" in d:
        return "damaging_goodfaith"
    if "articlequality" in d:
        return "articlequality"
    return "other"

df_contrib_ores["ores_model"] = df_contrib_ores["oresscores"].apply(get_ores_model_type)
df_contrib_ores["ores_model"].value_counts()
# Out:
# ores_model
# none                  676491
# draftquality            1163
# damaging_goodfaith      1129
# articlequality           788
# Name: count, dtype: int64

# %%
df_contrib_ores = df_contrib_ores[
    (df_contrib_ores["ores_model"] != "none") &
    (df_contrib_ores["ores_model"] != "articlequality")
]

ores_by_user = (
    df_contrib_ores
    .groupby(["user", "ores_model"])
    .size()
    .unstack(fill_value=0)
)

ores_by_user_ratio = ores_by_user.div(
    ores_by_user.sum(axis=1), axis=0
)

ores_by_user_ratio.plot(
    kind="bar",
    stacked=True,
    figsize=(12, 5)
)
plt.ylabel("Proportion of edits")
plt.title("ORES model distribution per user")
plt.legend(title="ORES model", bbox_to_anchor=(1.02, 1))
plt.tight_layout()
plt.show()

# %%
df_contrib_ores[df_contrib_ores['ores_model'] == 'damaging_goodfaith']

def extract_damaging_goodfaith(d):
    """
    Extracts damaging / goodfaith probabilities from an ORES output.

    Returns:
    - p_damaging: P(edit is damaging)
    - p_goodfaith: P(edit is made in good faith)
    """
    if (
        d is None
        or not isinstance(d, dict)
        or "damaging" not in d
        or "goodfaith" not in d
    ):
        return pd.Series({
            "p_damaging": np.nan,
            "p_goodfaith": np.nan
        })

    try:
        return pd.Series({
            "p_damaging": d["damaging"].get("true", np.nan),
            "p_goodfaith": d["goodfaith"].get("true", np.nan)
        })
    except Exception:
        return pd.Series({
            "p_damaging": np.nan,
            "p_goodfaith": np.nan
        })

mask = df_contrib["ores_model"] == "damaging_goodfaith"

dg_scores = df_contrib_ores.loc[mask, "oresscores"].apply(
    extract_damaging_goodfaith
)

df_contrib_ores.loc[mask, ["p_damaging", "p_goodfaith"]] = dg_scores

df_dg = df_contrib_ores[df_contrib_ores["ores_model"] == "damaging_goodfaith"]

df_dg[["p_damaging", "p_goodfaith"]].hist(
    bins=50,
    figsize=(10, 4)
)
plt.suptitle("Distribution of ORES damaging / goodfaith scores")
plt.show()

# %%
df_contrib[df_contrib['ores_model'] == 'other']
# Out:
#                  user    pageid  ns  \
# 0                LSGH  63260687   0
# 1                LSGH  63339598  10
# 2                LSGH  63281706   0
# 3                LSGH  63353757  10
# 4                LSGH  63262762   0
# ...               ...       ...  ..
# 679566  217.118.81.18  29636778   0
# 679567  217.118.81.18   2079383   0
# 679568  217.118.81.18  18577625   0
# 679569  217.118.81.18    154309   0
# 679570  217.118.81.18    154309   0
#
#                                                     title  \
# 0                            COVID-19 pandemic in Bahrain
# 1       Template:COVID-19 pandemic data/South Africa m...
# 2                             COVID-19 pandemic in Latvia
# 3       Template:COVID-19 pandemic data/Latvia medical...
# 4                            COVID-19 pandemic in Andorra
# ...                                                   ...
# 679566                                       2011 Ykkönen
# 679567                                           FC Honka
# 679568                           Culture Club discography
# 679569                                       Culture Club
# 679570                                       Culture Club
#
#                    timestamp                              comment  sizediff  \
# 0       2022-03-04T04:03:16Z  Updating number of cases in infobox         0
# 1       2022-03-04T04:01:40Z  Adding number of cases for March 03        33
# 2       2022-03-03T13:19:02Z  Updating number of cases in infobox         0
# 3       2022-03-03T13:18:11Z  Adding number of cases for March 03        30
# 4       2022-03-03T13:17:26Z  Updating number of cases in infobox         0
# ...                      ...                                  ...       ...
# 679566  2011-04-02T13:51:57Z                       /* Overview */         0
# 679567  2011-04-02T10:41:15Z                  /* Current squad */       118
# 679568  2010-09-09T20:38:22Z                  /* Studio albums */       -15
# 679569  2010-09-09T20:36:54Z                    /* Discography */         0
# 679570  2010-09-09T20:09:42Z                    /* Discography */        -2
#
#                   tags oresscores       user_type ores_model
# 0       ['wikieditor']         []      Registered      other
# 1       ['wikieditor']         []      Registered      other
# 2       ['wikieditor']         []      Registered      other
# 3       ['wikieditor']         []      Registered      other
# 4       ['wikieditor']         []      Registered      other
# ...                ...        ...             ...        ...
# 679566              []         []  Anonymous (IP)      other
# 679567              []         []  Anonymous (IP)      other
# 679568              []         []  Anonymous (IP)      other
# 679569              []         []  Anonymous (IP)      other
# 679570              []         []  Anonymous (IP)      other
#
# [676491 rows x 11 columns]

# %% [markdown]
# ## Tags

# %%
print(df_contrib_clean['tags'].unique())
# Out:
# ["['wikieditor']" "['discussiontools-added-comment', 'wikieditor']"
#  "['mw-reverted', 'discussiontools-added-comment', 'wikieditor']" '[]'
#  "['discussiontools-added-comment']" "['disambiguator-link-added']"
#  "['mw-reverted', 'discussiontools-added-comment']" "['mw-manual-revert']"
#  "['mw-reverted']" "['mw-new-redirect']" "['mw-undo']"
#  "['mw-undo', 'mw-reverted']" "['mw-undo', 'mw-new-redirect']"
#  "['mw-undo', 'nowiki added']" "['mw-undo', 'self-published source']"
#  "['mw-undo', 'possible libel or vandalism']"
#  "['mobile edit', 'mobile app edit', 'ios app edit', 'advanced mobile edit', 'app-section-source']"
#  "['visualeditor']" "['visualeditor', 'editcheck-newreference']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit']"
#  "['visualeditor', 'mw-reverted', 'editcheck-newreference']"
#  "['visualeditor', 'editcheck-references', 'editcheck-newcontent']"
#  "['visualeditor', 'mw-reverted', 'editcheck-references', 'editcheck-newcontent']"
#  "['visualeditor', 'mw-reverted']"
#  "['visualeditor', 'editcheck-newreference', 'editcheck-newcontent']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'editcheck-newreference', 'editcheck-newcontent']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'editcheck-references', 'editcheck-newcontent']"
#  "['mobile edit', 'mobile app edit', 'ios app edit', 'app-section-source']"
#  "['visualeditor-wikitext']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-reverted']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'disambiguator-link-added']"
#  "['mobile edit', 'mobile app edit', 'ios app edit']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'mw-manual-revert']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'advanced mobile edit', 'wikieditor']"
#  "['visualeditor-switched', 'wikieditor']"
#  "['visualeditor', 'nowiki added']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'editcheck-newreference']"
#  "['mw-undo', 'wikieditor']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-reverted', 'wikieditor']"
#  "['visualeditor', 'mw-manual-revert']"
#  "['visualeditor-wikitext', 'mw-reverted']"
#  "['visualeditor', 'editcheck-newcontent']"
#  "['visualeditor', 'editcheck-references', 'editcheck-newreference', 'editcheck-newcontent']"
#  "['visualeditor-wikitext', 'mw-manual-revert']"
#  "['mw-undo', 'mw-reverted', 'wikieditor']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'editcheck-newcontent']"
#  "['visualeditor', 'editcheck-references']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'mw-reverted']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'mw-blank', 'advanced mobile edit']"
#  "['visualeditor-wikitext', 'discussiontools-added-comment']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'advanced mobile edit']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'disambiguator-link-added']"
#  "['visualeditor-wikitext', 'mw-replace']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-visual', 'discussiontools-added-comment']"
#  "['visualeditor-wikitext', 'mw-blank']" "['visualeditor', 'mw-replace']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-reverted']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'mw-manual-revert', 'mw-reverted']"
#  "['mobile edit', 'mobile app edit', 'ios app edit', 'mw-reverted']"
#  "['discussiontools', 'discussiontools-visual', 'discussiontools-newtopic', 'discussiontools-added-comment']"
#  "['visualeditor', 'mw-manual-revert', 'mw-reverted']"
#  "['visualeditor-wikitext', 'nowiki added']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-manual-revert']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools-added-comment']"
#  "['visualeditor-switched']" "['visualeditor', 'deprecated source']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'nowiki added', 'advanced mobile edit']"
#  "['visualeditor', 'self-published-blog']" "['mw-undo', 'mw-replace']"
#  "['mobile edit', 'mobile app edit', 'ios app edit', 'advanced mobile edit']"
#  "['mobile edit', 'mobile web edit']" "['visualeditor', 'mw-blank']"
#  "['mobile edit', 'mobile web edit', 'visualeditor']"
#  "['mobile edit', 'mobile app edit']"
#  "['mobile edit', 'mobile web edit', 'visualeditor-switched']"
#  "['mw-new-redirect', 'wikieditor']"
#  "['mw-new-redirect', 'wikieditor', 'mw-recreated']"
#  "['disambiguator-link-added', 'wikieditor']"
#  "['mw-reverted', 'wikieditor']"
#  "['mw-changed-redirect-target', 'wikieditor']"
#  "['mw-manual-revert', 'wikieditor']"
#  "['discussiontools', 'discussiontools-source', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['mw-removed-redirect', 'wikieditor']"
#  "['mw-removed-redirect', 'disambiguator-link-added', 'wikieditor']"
#  "['nowiki added', 'wikieditor']"
#  "['disambiguator-link-added', 'discussiontools-added-comment', 'wikieditor']"
#  "['mw-replace', 'wikieditor']" "['wikieditor', 'mw-recreated']"
#  "['mw-new-redirect', 'wikieditor', 'uncategorized-redirect']"
#  "['mw-new-redirect', 'mw-manual-revert', 'wikieditor']"
#  "['self-published-blog', 'wikieditor']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['mw-manual-revert', 'mw-reverted', 'wikieditor']"
#  "['mw-changed-redirect-target', 'mw-manual-revert', 'mw-reverted', 'wikieditor']"
#  "['mw-changed-redirect-target', 'mw-manual-revert', 'wikieditor']"
#  "['mw-reverted', 'disambiguator-link-added', 'wikieditor']"
#  "['mobile edit', 'mobile web edit', 'mw-manual-revert']"
#  "['mobile edit', 'mobile web edit', 'mw-reverted']"
#  "['mw-new-redirect', 'mw-reverted', 'wikieditor']"
#  "['mw-removed-redirect', 'mw-reverted', 'wikieditor']"
#  "['nowiki added', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-removed-redirect']"
#  "['mw-changed-redirect-target', 'disambiguator-link-added']"
#  "['mw-changed-redirect-target']" "['nowiki added']"
#  "['mw-new-redirect', 'mw-manual-revert', 'mw-reverted']"
#  "['mw-new-redirect', 'mw-reverted']"
#  "['mw-changed-redirect-target', 'mw-manual-revert']" "['mw-blank']"
#  "['mw-undo', 'mw-removed-redirect']" "['Addition of interwiki link']"
#  "['adding email address']" "['large unwikified new article']"
#  "['mw-undo', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-new-redirect', 'mw-recreated']" "['mw-rollback']"
#  "['mw-rollback', 'mw-reverted']"
#  "['contentious topics alert', 'discussiontools-added-comment', 'wikieditor']"
#  "['mw-manual-revert', 'mw-reverted', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-rollback', 'disambiguator-link-added']"
#  "['mw-blank', 'wikieditor']"
#  "['mw-reverted', 'disambiguator-link-added', 'discussiontools-added-comment', 'wikieditor']"
#  "['mw-undo', 'mw-removed-redirect', 'wikieditor']"
#  "['mw-rollback', 'mw-new-redirect']"
#  "['mw-rollback', 'mw-removed-redirect', 'mw-reverted']"
#  "['mw-rollback', 'mw-removed-redirect']"
#  "['mw-manual-revert', 'discussiontools-added-comment', 'wikieditor']"
#  "['mw-manual-revert', 'disambiguator-link-added', 'wikieditor']"
#  "['wikieditor', 'harv-error']"
#  "['mw-replace', 'discussiontools-added-comment', 'wikieditor']"
#  "['deprecated source', 'discussiontools-added-comment', 'wikieditor']"
#  "['contentious topics alert', 'mw-reverted', 'discussiontools-added-comment', 'wikieditor']"
#  "['mw-undo', 'nowiki added', 'wikieditor']"
#  "['mw-rollback', 'mw-reverted', 'disambiguator-link-added']"
#  "['mw-undo', 'mw-reverted', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-undo', 'mw-changed-redirect-target', 'wikieditor']"
#  "['mw-undo', 'mw-new-redirect', 'wikieditor']"
#  "['mw-removed-redirect', 'mw-manual-revert', 'wikieditor']"
#  "['mw-changed-redirect-target', 'mw-reverted', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-undo', 'mw-changed-redirect-target', 'mw-reverted', 'wikieditor']"
#  "['mw-undo', 'mw-removed-redirect', 'mw-reverted', 'wikieditor']"
#  "['mw-removed-redirect', 'discussiontools-added-comment', 'wikieditor']"
#  "['mw-changed-redirect-target', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-undo', 'mw-changed-redirect-target', 'disambiguator-link-added', 'wikieditor']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced']"
#  "['mw-blank', 'mw-manual-revert', 'wikieditor']"
#  "['mw-changed-redirect-target', 'mw-manual-revert', 'disambiguator-link-added', 'wikieditor']"
#  "['mw-rollback', 'mw-new-redirect', 'mw-reverted']"
#  "['mw-manual-revert', 'disambiguator-link-added']"
#  "['mw-manual-revert', 'mw-reverted']"
#  "['mw-manual-revert', 'discussiontools-added-comment']"
#  "['mw-undo', 'disambiguator-link-added']"
#  "['disambiguator-link-added', 'discussiontools-added-comment']"
#  "['contentious topics alert']" "['mw-blank', 'mw-manual-revert']"
#  "['mw-changed-redirect-target', 'mw-reverted']"
#  "['mw-blank', 'mw-manual-revert', 'mw-reverted']"
#  "['mw-blank', 'mw-reverted']" "['mw-replace']"
#  "['nowiki added', 'mw-manual-revert']"
#  "['mw-undo', 'mw-changed-redirect-target']"
#  "['mw-undo', 'contentious topics alert']" "['deprecated source']"
#  "['mw-rollback', 'mw-changed-redirect-target']"
#  "['mw-undo', 'mw-rollback']"
#  "['mobile edit', 'mobile web edit', 'mw-new-redirect', 'advanced mobile edit']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools', 'discussiontools-source', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools', 'discussiontools-source', 'mw-reverted', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'mw-changed-redirect-target', 'advanced mobile edit']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'mw-changed-redirect-target', 'advanced mobile edit', 'wikieditor']"
#  "['mobile edit', 'mobile web edit', 'mw-changed-redirect-target', 'advanced mobile edit', 'mw-reverted']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-reverted', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools', 'discussiontools-source', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'mw-new-redirect', 'advanced mobile edit', 'uncategorized-redirect']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'mw-reverted', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'mw-replace', 'advanced mobile edit', 'wikieditor']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-reverted', 'disambiguator-link-added']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'deprecated source']"
#  "['discussiontools', 'discussiontools-source', 'discussiontools-newtopic', 'discussiontools-source-enhanced']"
#  "['discussiontools', 'discussiontools-source', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['mobile edit', 'mobile web edit', 'mw-new-redirect']"
#  "['mobile edit', 'mobile web edit', 'mw-changed-redirect-target']"
#  "['mw-undo', 'mobile edit', 'mobile web edit']"
#  "['mobile edit', 'mobile web edit', 'mw-replace']"
#  "['ProveIt edit', 'wikieditor']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'mw-manual-revert', 'mw-reverted']"
#  "['ProveIt edit']"
#  "['mw-undo', 'mobile edit', 'mobile web edit', 'advanced mobile edit', 'disambiguator-link-added']"
#  "['mw-manual-revert', 'mw-reverted', 'disambiguator-link-added']"
#  "['mw-removed-redirect', 'mw-reverted']"
#  "['visualeditor', 'mw-new-redirect']" "['mw-undo', 'twinkle']"
#  "['mw-new-redirect', 'visualeditor-switched']" "['mobile edit']"
#  "['Redirect becoming article']" "['self-published-blog']"
#  "['mw-replace', 'mw-manual-revert']" "['mw-replace', 'mw-reverted']"
#  "['very short new article']" "['End of page text']"
#  "['mw-new-redirect', 'visualeditor-switched', 'wikieditor']"
#  "['discussiontools', 'discussiontools-source', 'mw-reverted', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'mw-reverted', 'discussiontools-source-enhanced', 'disambiguator-link-added']"
#  "['visualeditor-switched', 'mw-reverted', 'wikieditor']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced']"
#  "['twinkle', 'discussiontools-added-comment']"
#  "['twinkle', 'mw-reverted']" "['twinkle']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['twinkle', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['visualeditor', 'mw-changed-redirect-target']"
#  "['mw-undo', 'twinkle', 'mw-reverted']" "['shortdesc helper']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-visual']"
#  "['visualeditor', 'disambiguator-link-added']"
#  "['mw-new-redirect', 'visualeditor-switched', 'disambiguator-link-added', 'wikieditor']"
#  "['visualeditor', 'mw-changed-redirect-target', 'mw-manual-revert']"
#  "['mobile edit', 'mobile web edit', 'mw-rollback', 'advanced mobile edit']"
#  "['mw-new-redirect', 'disambiguator-link-added', 'wikieditor']"
#  "['visualeditor-switched', 'mw-manual-revert', 'wikieditor']"
#  "['visualeditor', 'mw-changed-redirect-target', 'mw-manual-revert', 'disambiguator-link-added']"
#  "['visualeditor', 'mw-reverted', 'editcheck-newreference', 'editcheck-newcontent']"
#  "['visualeditor-switched', 'mw-removed-redirect', 'wikieditor']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced', 'disambiguator-link-added']"
#  "['contentious topics alert', 'discussiontools', 'discussiontools-source', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['twinkle', 'mw-reverted', 'discussiontools-added-comment']"
#  "['visualeditor', 'mw-removed-redirect', 'disambiguator-link-added']"
#  "['mobile edit', 'mobile web edit', 'advanced mobile edit', 'discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['visualeditor', 'mw-reverted', 'possible BLPCRIME issue']"
#  "['visualeditor', 'mw-reverted', 'editcheck-references']"
#  "['mw-changed-redirect-target', 'mw-reverted', 'wikieditor']"
#  "['contentious topics alert', 'discussiontools', 'discussiontools-source', 'mw-reverted', 'discussiontools-newtopic', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['discussiontools', 'discussiontools-reply', 'discussiontools-source', 'mw-reverted', 'discussiontools-source-enhanced']"
#  "['mw-undo', 'mw-removed-redirect', 'twinkle']"
#  "['visualeditor', 'mw-removed-redirect', 'editcheck-references']"
#  "['mobile edit', 'mobile web edit', 'visualeditor', 'advanced mobile edit', 'editcheck-references']"
#  "['mw-changed-redirect-target', 'visualeditor-switched', 'mw-reverted', 'wikieditor']"
#  "['visualeditor', 'nowiki added', 'disambiguator-link-added']"
#  "['visualeditor', 'mw-removed-redirect']"
#  "['deprecated source', 'discussiontools', 'discussiontools-reply', 'discussiontools-source', 'discussiontools-source-enhanced', 'discussiontools-added-comment']"
#  "['twinkle', 'mw-reverted', 'disambiguator-link-added', 'discussiontools-added-comment']"
#  "['twinkle', 'disambiguator-link-added']"
#  "['contentious topics alert', 'wikieditor']"
#  "['mw-changed-redirect-target', 'visualeditor-switched', 'wikieditor']"
#  "['mw-new-redirect', 'disambiguator-link-added']"
#  "['visualeditor-switched', 'mw-reverted']"
#  "['mw-new-redirect', 'visualeditor-switched', 'disambiguator-link-added']"
#  "['mw-removed-redirect', 'twinkle']"
#  "['visualeditor-switched', 'mw-removed-redirect']"
#  "['visualeditor-switched', 'mw-removed-redirect', 'mw-reverted']"
#  "['contentious topics alert', 'discussiontools-added-comment']"
#  "['deprecated source', 'discussiontools-added-comment']"
#  "['contentious topics alert', 'mw-reverted']"
#  "['contenttranslation', 'contenttranslation-v2']"
#  "['mw-changed-redirect-target', 'visualeditor-switched']"
#  "['nowiki added', 'visualeditor-switched']"
#  "['mw-changed-redirect-target', 'mw-manual-revert', 'mw-reverted']"
#  "['visualeditor-wikitext', 'mw-new-redirect']" "['Section blanking']"
#  "['references removed']"]

# %%
usernames
# Out:
# array(['LSGH', 'TheDraperyFalls', 'Aleksandr Grigoryev', 'Toddy1', 'UP9',
#        'Yulia Romero', 'Irpen', 'Seryo93', 'Dbachmann', 'Mzajac',
#        '94.178.235.125', '77.252.47.155', '124.190.40.8',
#        '212.137.36.230', '24.183.100.38', '61.102.45.248',
#        '174.3.111.148', '172.202.173.230', '217.118.81.21',
#        '217.118.81.18'], dtype=object)
