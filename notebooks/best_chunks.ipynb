# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from dhlab_utils.implementation import *

import sys
import os

# Add the project root to Python's module search path
sys.path.append(os.path.abspath(".."))

# %%
fg_user_known = pd.read_csv('../datas/interim/fg_user_known.csv')

# %%
best_chunk = pd.read_csv('../datas/interim/best_chunk_agree.csv')

# %%
best_chunk_agree = best_chunk[
    (best_chunk['Annot 1 - new'] == 'Correct') &
    (best_chunk['Annot 2 - new'] == 'Correct') &
    (best_chunk['Column 1'] == 'Agree')
].reset_index(drop=True)

# %%
best_chunk['username'] = 'unknown'
best_chunk['date'] = 'unknown'
best_chunk['article'] = 'unknown'
