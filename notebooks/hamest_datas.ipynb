# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Details about Wikipedia's users
#
# - User can be an IP adress --> IP users, guest users, or unregistered users are users who edit Wikipedia without registering for an account.
# - User can be a Bot --> automatic editing
# - User can be a registred user --> nickname or full name

# %% [markdown]
# ### Bots
#
# Let's focus on Bot at first because it feels weird that bots can edit Wikipedia's article. Apparently, bots are registered and approved. They must :
# * Have a separate, clearly labeled account (usually ending with “Bot”, like ClueBot NG).
# * Get approval from the community through the “Bot Approvals Group” process.
# * Be limited in scope to well-defined, repetitive tasks (like fixing typos, reverting vandalism, adding categories, or updating statistics).
# So, bots don’t randomly modify articles — they work under strict rules.

# %%
best_chunks = pd.read_excel("datas/previous-project/Hedi/best_chunks_semi_automated_annotated_data_repaired.xlsx")
best_chunks = best_chunks[best_chunks['Annot 1'].fillna('') == 'Correct']
best_chunks = best_chunks[best_chunks['Annot 2'].fillna('') == 'Correct']
best_chunks = best_chunks[best_chunks['Annot 1 - new'].fillna('') == 'Correct']
best_chunks = best_chunks[best_chunks['Annot 2 - new'].fillna('') == 'Correct']

best_chunks.head(10)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#     row_index                                    detected_before  \
# 0           6  A referendum in the largely ethnic Russian [[A...
# 2          10  In 1940, after securing the assent of Nazi Ger...
# 3          11  Although local Ukrainians have unsuccesfully a...
# 12         56  {{Expert-portal|Music}}\n{{Ukrainianmusic}}\n\...
# 13         60  The following day, the illegally elected Russi...
# 22        106  The Soviet Union, founded three decades before...
# 23        109  To the east there are the south-western spurs ...
# 24        115  Historians have debated the long-term influenc...
# 27        119  {{current|date=March 2014}}\n'''Crimea's acces...
# 32        129  {{current|date=March 2014}}\n'''Crimea's acces...
#
#                                        detected_after  \
# 0   A referendum in the largely ethnic Russian [[A...
# 2   In 1940, after securing the assent of Nazi Ger...
# 3   Although local Ukrainians have unsuccesfully a...
# 12  --- \n+++ \n@@ -1,10 +1,10 @@\n-'''Ethnic Ukra...
# 13  The following day, the newly elected Russian m...
# 22  The Soviet Union, found three decades before t...
# 23  To the east there are the south-western spurs ...
# 24  Historians have debated the long-term influenc...
# 27  --- \n+++ \n@@ -15,7 +15,7 @@\n | blank2_label...
# 32  --- \n+++ \n@@ -60,7 +60,7 @@\n | casualties_l...
#
#                                          clean_before  \
# 0   A referendum in the largely ethnic Russian Ukr...
# 2   In 1940, after securing the assent of Nazi Ger...
# 3   Although local Ukrainians have unsuccesfully a...
# 12  ''Ethnic Ukrainian music''' includes many vari...
# 13  The following day, the illegally elected Russi...
# 22  The Soviet Union, founded three decades before...
# 23  To the east there are the south-western spurs ...
# 24  Historians have debated the long-term influenc...
# 27  ''Crimea's accession to Russia''' is an ongoin...
# 32  ''Crimea's accession to Russia''' is an ongoin...
#
#                                           clean_after  \
# 0   A referendum in the largely ethnic Russian Ukr...
# 2   In 1940, after securing the assent of Nazi Ger...
# 3   Although local Ukrainians have unsuccesfully a...
# 12  --- \n+++ \n@@ -1,10 +1,10 @@\n-'''Ethnic Ukra...
# 13  The following day, the newly elected Russian m...
# 22  The Soviet Union, found three decades before t...
# 23  To the east there are the south-western spurs ...
# 24  Historians have debated the long-term influenc...
# 27  --- \n+++ \n@@ -15,7 +15,7 @@\n | blank2_label...
# 32  --- \n+++ \n@@ -60,7 +60,7 @@\n | casualties_l...
#
#                         type_of_change_extracted  category_extracted_clean  \
# 0   rephrasing and addition of descriptive terms  Terminology Manipulation
# 2              rewording and addition of context  Terminology Manipulation
# 3                           addition of a phrase  Terminology Manipulation
# 12                      rephrasing and rewording  Terminology Manipulation
# 13                                  synonym swap  Terminology Manipulation
# 22                   synonym swap and rephrasing  Terminology Manipulation
# 23                                linking a term  Terminology Manipulation
# 24                            Terminology change  Terminology Manipulation
# 27                                    rephrasing  Terminology Manipulation
# 32                                    rephrasing  Terminology Manipulation
#
#     propaganda_similarity category_extracted_propaganda_mapped  \
# 0                0.418396   Obfuscation, intentional vagueness
# 2                0.418396   Obfuscation, intentional vagueness
# 3                0.418396   Obfuscation, intentional vagueness
# 12               0.418396   Obfuscation, intentional vagueness
# 13               0.418396   Obfuscation, intentional vagueness
# 22               0.418396   Obfuscation, intentional vagueness
# 23               0.418396   Obfuscation, intentional vagueness
# 24               0.418396   Obfuscation, intentional vagueness
# 27               0.418396   Obfuscation, intentional vagueness
# 32               0.418396   Obfuscation, intentional vagueness
#
#                                  aligned_before_chunk  \
# 0   A referendum in the largely ethnic Russian Ukr...
# 2   In 1940, after securing the assent of Nazi Ger...
# 3   Although local Ukrainians have unsuccesfully a...
# 12  ''Ethnic Ukrainian music''' includes many vari...
# 13  The following day, the illegally elected Russi...
# 22  The Soviet Union, founded three decades before...
# 23  To the east there are the south-western spurs ...
# 24  Historians have debated the long-term influenc...
# 27  ''Crimea's accession to Russia''' is an ongoin...
# 32  The next day after the 2014 Crimean referendum...
#
#                                   aligned_after_chunk  similarity  \
# 0   A referendum in the largely ethnic Russian Ukr...    0.925267
# 2   In 1940, after securing the assent of Nazi Ger...    0.981235
# 3   Although local Ukrainians have unsuccesfully a...    0.947917
# 12  'Ethnic Ukrainian music''' includes many varie...    0.938581
# 13  The following day, the newly elected Russian m...    0.977270
# 22  The Soviet Union, found three decades before t...    0.898906
# 23  To the east there are the south-western spurs ...    1.000000
# 24  Historians have debated the long-term influenc...    0.935329
# 27  \n+The '''accession of Republic of Crimea to t...    0.883564
# 32  The political crisis surrounding the annexatio...    0.731152
#
#                                significance_extracted  Annot 1  Annot 2  \
# 0   The use of terms like 'bloodless' and 'bloody ...  Correct  Correct
# 2   The change from 'annex' to 'invade and occupy'...  Correct  Correct
# 3   The addition of 'the policies of Rumanization ...  Correct  Correct
# 12  The edit shifts the terminology from 'Ethnic U...  Correct  Correct
# 13  This change alters the perception of the legit...  Correct  Correct
# 22  This edit employs derogatory language and rebr...  Correct  Correct
# 23  The change emphasizes the term 'Russia' by lin...  Correct  Correct
# 24  This change shifts the focus from the specific...  Correct  Correct
# 27  The change from 'Autonomous Republic of Crimea...  Correct  Correct
# 32  The change from 'Crimea's accession to Russia'...  Correct  Correct
#
#    Annot 1 - new Annot 2 - new Column 1
# 0        Correct       Correct    Agree
# 2        Correct       Correct    Agree
# 3        Correct       Correct    Agree
# 12       Correct       Correct    Agree
# 13       Correct       Correct    Agree
# 22       Correct       Correct    Agree
# 23       Correct       Correct    Agree
# 24       Correct       Correct    Agree
# 27       Correct       Correct    Agree
# 32       Correct       Correct    Agree
