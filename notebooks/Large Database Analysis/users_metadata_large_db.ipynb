# %% [markdown]
# # User's metadata Analysis
#
# This notebook helps to retrieve, analyse and visualize user's metadata for all the users from the **large** database (>19'000 unique users).
#
# In particular, this notebook contains :
# * reusable functions for any users in Wikipedia
# * plots visualization to see patterns
# * analysis of the results to understand the impact of the metadata of a user and his editing behaviour.
#
# We retrieved metadata through Wikipedia's API using the ```action=query``` endpoint with ```list=users``` and the parameters ```ucprop=blockinfo|groups|editcount|registration|emailable|gender```.
#
# The final goal of this notebook is find some features that reveals certain weaponizing patterns that can retrieved and keep for the developpement of an LLM.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import calendar
from datetime import timedelta
from scipy.stats import variation
from tqdm import tqdm

# %%
# import our small preprocessed database
df = pd.read_csv('../../datas/final/large_db_preprocess.csv')

# %%
# Users list
top10_registered_users = df["user"].value_counts().head(10).index.tolist()
users_list = df['user'].unique().tolist()
df_ip = df[df['user_type'] == 'Anonymous (IP)']
top10_ip_users = df_ip["user"].value_counts().head(10).index.tolist()

# load users metadata retrieved using wikipedia API
df_all_user_metadata = pd.read_csv('../../datas/interim/Large Database Analysis/users_metadata_df.csv')

# %%
# after cleaning, we merge the metadata dataframe to the database

df_all_user_metadata=df_all_user_metadata.dropna(axis='index', how='any', subset=['registration'])
df_all_user_metadata = df_all_user_metadata.rename(columns={"name": "user"})
df_enriched = df.merge(
    df_all_user_metadata,
    on="user",
    how="left"
)

# %%
df_enriched
# Out:
#                                          initial_version  \
# 0      {{main|2020 coronavirus outbreak in Europe}}\n...
# 1      {{main|2020 coronavirus outbreak in Europe}}\n...
# 2      {{main|2020 coronavirus outbreak in Europe}}\n...
# 3      {{main|2020 coronavirus outbreak in Europe}}\n...
# 4      {{main|2020 coronavirus outbreak in Europe}}\n...
# ...                                                  ...
# 69897  {{under construction}}\n{{Infobox civil confli...
# 69898  {{under construction}}\n{{Infobox civil confli...
# 69899  {{under construction}}\n{{Infobox civil confli...
# 69900  {{under construction}}\n{{Infobox civil confli...
# 69901  {{under construction}}\n{{Infobox civil confli...
#
#                                          changed_version  \
# 0                                       Initial revision
# 1      --- \n+++ \n@@ -10,7 +10,7 @@\n | virus_strain...
# 2      --- \n+++ \n@@ -17,7 +17,7 @@\n \n == Timeline...
# 3      --- \n+++ \n@@ -17,7 +17,7 @@\n | recovery_cas...
# 4      --- \n+++ \n@@ -1,5 +1,3 @@\n-{{see also|2019–...
# ...                                                  ...
# 69897  --- \n+++ \n@@ -101,7 +101,7 @@\n Ukrainians h...
# 69898  --- \n+++ \n@@ -376,7 +376,7 @@\n \n On 9 Dece...
# 69899  --- \n+++ \n@@ -274,7 +274,7 @@\n \n On 24 Dec...
# 69900  --- \n+++ \n@@ -274,7 +274,7 @@\n \n On 24 Dec...
# 69901  --- \n+++ \n@@ -512,14 +512,12 @@\n \n ==Exter...
#
#                                                  comment  \
# 0                                            create page
# 1      changed arrival_date 2020.03.03 in [[Template:...
# 2                                                    NaN
# 3                                                    NaN
# 4      /* top */ [[WP:HATNOTES|hatnotes]] are used if...
# ...                                                  ...
# 69897                                 [[Yuriy Lutsenko]]
# 69898                      /* Protests across Ukraine */
# 69899                          /* 18 December–present */
# 69900                          /* 18 December–present */
# 69901                               /* External links */
#
#                                user                  date  \
# 0                             Dying  2020-03-03T23:46:58Z
# 1                           Neo-Jay  2020-03-04T00:05:02Z
# 2      Unlogged by Anti-1337 People  2020-03-11T10:54:13Z
# 3                             1857a  2020-03-04T00:54:47Z
# 4                           Uanfala  2020-03-05T19:12:54Z
# ...                             ...                   ...
# 69897                        Nickst  2013-12-25T18:38:02Z
# 69898                       Lvivske  2013-12-26T00:29:34Z
# 69899                       Lvivske  2013-12-25T19:25:39Z
# 69900                       Lvivske  2013-12-25T23:28:06Z
# 69901                       Lvivske  2013-12-26T00:11:40Z
#
#                                               llm_output      weaponised  \
# 0      Added initial revision content.\n\nNot Weaponi...  Not Weaponised
# 1      Changed the format of the arrival date from "2...  Not Weaponised
# 2      Changed the date from "27 January 2020" to "27...  Not Weaponised
# 3      Changed the date format from "2020.03.03" to "...  Not Weaponised
# 4      Removed two hatnote templates related to the 2...  Not Weaponised
# ...                                                  ...             ...
# 69897  Changed "Yuri Lutsenko" to "Yuriy Lutsenko" in...  Not Weaponised
# 69898  The change made is: "Rephrased the number of t...      Weaponised
# 69899  The change made is the addition of the phrase ...  Not Weaponised
# 69900  The change made is a rephrasing of a statement...      Weaponised
# 69901  **Change Description:** Added a new external l...      Weaponised
#
#                             article   user_type  editcount  ... blockexpiry  \
# 0      COVID-19 pandemic in Ukraine  Registered    11773.0  ...         NaN
# 1      COVID-19 pandemic in Ukraine  Registered    53888.0  ...         NaN
# 2      COVID-19 pandemic in Ukraine  Registered       35.0  ...    infinite
# 3      COVID-19 pandemic in Ukraine  Registered    10623.0  ...         NaN
# 4      COVID-19 pandemic in Ukraine  Registered    65714.0  ...         NaN
# ...                             ...         ...        ...  ...         ...
# 69897                    Euromaidan  Registered        NaN  ...         NaN
# 69898                    Euromaidan  Registered    26519.0  ...         NaN
# 69899                    Euromaidan  Registered    26519.0  ...         NaN
# 69900                    Euromaidan  Registered    26519.0  ...         NaN
# 69901                    Euromaidan  Registered    26519.0  ...         NaN
#
#       blocknocreate blockedtimestampformatted  blockowntalk  blockemail  \
# 0               NaN                       NaN           NaN         NaN
# 1               NaN                       NaN           NaN         NaN
# 2               NaN      11:21, 11 March 2020           NaN         NaN
# 3               NaN                       NaN           NaN         NaN
# 4               NaN                       NaN           NaN         NaN
# ...             ...                       ...           ...         ...
# 69897           NaN                       NaN           NaN         NaN
# 69898           NaN                       NaN           NaN         NaN
# 69899           NaN                       NaN           NaN         NaN
# 69900           NaN                       NaN           NaN         NaN
# 69901           NaN                       NaN           NaN         NaN
#
#       missing  blockexpiryformatted blockexpiryrelative blockpartial invalid
# 0         NaN                   NaN                 NaN          NaN     NaN
# 1         NaN                   NaN                 NaN          NaN     NaN
# 2         NaN                   NaN                 NaN          NaN     NaN
# 3         NaN                   NaN                 NaN          NaN     NaN
# 4         NaN                   NaN                 NaN          NaN     NaN
# ...       ...                   ...                 ...          ...     ...
# 69897     NaN                   NaN                 NaN          NaN     NaN
# 69898     NaN                   NaN                 NaN          NaN     NaN
# 69899     NaN                   NaN                 NaN          NaN     NaN
# 69900     NaN                   NaN                 NaN          NaN     NaN
# 69901     NaN                   NaN                 NaN          NaN     NaN
#
# [69902 rows x 29 columns]

# %% [markdown]
# ## Gender

# %%
df_all_user_metadata['gender'].value_counts()
# Out:
# gender
# unknown    6658
# male       2147
# female      222
# Name: count, dtype: int64

# %%
pd.crosstab(
    df_enriched['gender'],
    df_enriched['weaponised'],
    normalize='index'
).mul(100).plot.bar(
    figsize=(8,5),
    title="Weaponised vs Non-Weaponised Edits by Gender",
    ylabel="Percentage of Edits (%)"
)
# Out:
# <Axes: title={'center': 'Weaponised vs Non-Weaponised Edits by Gender'}, xlabel='gender', ylabel='Percentage of Edits (%)'>

# %% [markdown]
# ## Block

# %%
df_all_user_metadata_block = df_all_user_metadata.dropna(axis='index', how='any', subset=['blockid'])
df_all_user_metadata_block
# Out:
#                               user  editcount          registration  \
# 2     Unlogged by Anti-1337 People       35.0  2020-03-11T10:39:30Z
# 19                      CLCStudent   315516.0  2015-09-30T19:37:10Z
# 23                          Adûnâi     4023.0  2014-07-17T20:52:01Z
# 32                       Tvorozhok        8.0  2020-03-20T03:40:34Z
# 49                          DePiep   294285.0  2005-02-26T14:48:50Z
# ...                            ...        ...                   ...
# 9031                    Priharisid      185.0  2024-07-12T22:58:29Z
# 9035                Rochambeau1783     6134.0  2020-08-08T08:46:02Z
# 9036                       Bildete     3145.0  2024-11-06T16:03:09Z
# 9052                    Euromaidan        1.0  2013-11-26T09:20:51Z
# 9065                 Steven Rogers      556.0  2013-04-23T08:47:02Z
#
#                                                  groups   gender  emailable  \
# 2                        ['*', 'user', 'autoconfirmed']  unknown        NaN
# 19    ['extendedconfirmed', 'reviewer', '*', 'user',...     male        NaN
# 23    ['extendedconfirmed', '*', 'user', 'autoconfir...  unknown        NaN
# 32                                        ['*', 'user']  unknown        NaN
# 49    ['extendedconfirmed', '*', 'user', 'autoconfir...  unknown        NaN
# ...                                                 ...      ...        ...
# 9031                     ['*', 'user', 'autoconfirmed']  unknown        NaN
# 9035  ['extendedconfirmed', '*', 'user', 'autoconfir...  unknown        NaN
# 9036  ['extendedconfirmed', '*', 'user', 'autoconfir...  unknown        NaN
# 9052                                      ['*', 'user']  unknown        NaN
# 9065                     ['*', 'user', 'autoconfirmed']  unknown        NaN
#
#          blockid     blockedby  blockedbyid  \
# 2      9661252.0      Bishonen      85193.0
# 19    10405207.0  TonyBallioni    5527268.0
# 23     9991115.0  Ohnoitsjamie     507787.0
# 32     9678808.0     Ymblanter   14596827.0
# 49    19499496.0        Tamzin   17820167.0
# ...          ...           ...          ...
# 9031  25075296.0         DrKay    2387872.0
# 9035  25259627.0    Asilvering   42788136.0
# 9036  25273698.0     Blablubbs   22922645.0
# 9052   4839064.0       Yunshui   10345689.0
# 9065   6446180.0      AmandaNP    5759406.0
#
#                                             blockreason  ... blockexpiry  \
# 2     [[WP:Vandalism-only account|Vandalism-only acc...  ...    infinite
# 19                           {{checkuserblock-account}}  ...    infinite
# 23    [[WP:No personal attacks|Personal attacks]] or...  ...    infinite
# 32    [[WP:Vandalism-only account|Vandalism-only acc...  ...    infinite
# 49    [[WP:CBAN|Sitebanned by the community]] per [[...  ...    infinite
# ...                                                 ...  ...         ...
# 9031  Persistent addition of [[WP:INTREF|unsourced c...  ...    infinite
# 9035  {{checkuserblock-account}}: Abusing [[WP:SOCK|...  ...    infinite
# 9036  Abusing [[WP:SOCK|multiple accounts]]: Please ...  ...    infinite
# 9052                                 {{uw-softerblock}}  ...    infinite
# 9065                         {{checkuserblock-account}}  ...    infinite
#
#      blocknocreate  blockedtimestampformatted blockowntalk  blockemail  \
# 2              NaN       11:21, 11 March 2020          NaN         NaN
# 19             NaN    21:59, 23 February 2021          NaN         NaN
# 23             NaN       14:05, 3 August 2020          NaN         NaN
# 32             NaN       06:37, 20 March 2020          NaN         NaN
# 49             NaN       11:42, 28 April 2023          NaN         NaN
# ...            ...                        ...          ...         ...
# 9031           NaN    22:42, 23 December 2024          NaN         NaN
# 9035           NaN     04:40, 26 October 2025          NaN         NaN
# 9036           NaN    11:51, 15 November 2025          NaN         NaN
# 9052           NaN    13:30, 27 November 2013          NaN         NaN
# 9065           NaN    09:05, 18 December 2015          NaN         NaN
#
#       missing  blockexpiryformatted blockexpiryrelative blockpartial  invalid
# 2         NaN                   NaN                 NaN          NaN      NaN
# 19        NaN                   NaN                 NaN          NaN      NaN
# 23        NaN                   NaN                 NaN          NaN      NaN
# 32        NaN                   NaN                 NaN          NaN      NaN
# 49        NaN                   NaN                 NaN          NaN      NaN
# ...       ...                   ...                 ...          ...      ...
# 9031      NaN                   NaN                 NaN          NaN      NaN
# 9035      NaN                   NaN                 NaN          NaN      NaN
# 9036      NaN                   NaN                 NaN          NaN      NaN
# 9052      NaN                   NaN                 NaN          NaN      NaN
# 9065      NaN                   NaN                 NaN          NaN      NaN
#
# [1007 rows x 21 columns]

# %%
df_all_user_metadata_block['gender'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df_all_user_metadata_block['editcount'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# get a valid date format for the registration date
df_all_user_metadata_block['registration'] = pd.to_datetime(
    df_all_user_metadata_block['registration'],
    errors='coerce'
)

# get a valid date format for the block date
df_all_user_metadata_block['blockedtimestamp'] = pd.to_datetime(
    df_all_user_metadata_block['blockedtimestamp'],
    errors='coerce'
)

# compute the difference between the 2
df_all_user_metadata_block['days_to_block'] = (
    df_all_user_metadata_block['blockedtimestamp']
    - df_all_user_metadata_block['registration']
).dt.days

# ensure the values are valid
df_all_user_metadata_block = df_all_user_metadata_block[
    df_all_user_metadata_block['days_to_block'] >= 0
]

# 6.9 percent of users blocked within the 24 hours after their account creation date
(df_all_user_metadata_block['days_to_block'] <= 1).mean() * 100
# Out:
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_88627/2805693770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_user_metadata_block['registration'] = pd.to_datetime(
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_88627/2805693770.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_user_metadata_block['blockedtimestamp'] = pd.to_datetime(
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_88627/2805693770.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all_user_metadata_block['days_to_block'] = (
# 10.02979145978153

# %%
df_all_user_metadata_block['days_to_block'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_enriched['is_blocked'] = df_enriched['blockid'].notna()

pd.crosstab(
    df_enriched['is_blocked'],
    df_enriched['weaponised'],
    normalize='index'
).mul(100).plot.bar(
    figsize=(8,5),
    title="Weaponised vs Non-Weaponised Edits by Block Status",
    ylabel="Percentage of Edits (%)",
    rot=0
)
# Out:
# <Axes: title={'center': 'Weaponised vs Non-Weaponised Edits by Block Status'}, xlabel='is_blocked', ylabel='Percentage of Edits (%)'>

# %% [markdown]
# ## Registration

# %%
def compute_account_age(df_metadata, registration_col="registration", output_col="account_age_days"):
    """
    Compute the account age (in days) for each user given a metadata dataframe.

    Parameters
    ----------
    df_metadata : pd.DataFrame
        DataFrame containing user-level metadata, including their registration timestamp.
    
    registration_col : str, optional
        Name of the column containing registration timestamps (default: "registration").
    
    output_col : str, optional
        Name of the output column where account age will be stored (default: "account_age_days").

    Returns
    -------
    pd.DataFrame
        Same dataframe with an additional column representing the account age in days.
    
    Notes
    -----
    - If registration date is missing or invalid, age will be set to NaN.
    - Uses UTC timestamps (as provided by the Wikipedia API).
    """
    
    df = df_metadata.copy()

    # Convert registration date to datetime
    df[registration_col] = pd.to_datetime(df[registration_col], errors="coerce")

    # Compute age
    df[output_col] = (pd.Timestamp.utcnow() - df[registration_col]).dt.days

    return df

df_enriched_registration = compute_account_age(df_enriched)
df_enriched_registration = df_enriched_registration[df_enriched_registration['user_type'] == 'Registered']

df_enriched_registration["weaponised_binary"] = (
    df_enriched_registration["weaponised"]
    .eq("Weaponised")
    .astype(int)
)

user_level = (
    df_enriched_registration
    .groupby(["user", "user_type"])
    .agg(
        account_age_days=("account_age_days", "first"),
        weaponised_rate=("weaponised_binary", "mean")
    )
)

user_level["age_bin"] = pd.qcut(user_level["account_age_days"], q=8)

pivot_user = (
    user_level
    .groupby(["user_type", "age_bin"])["weaponised_rate"]
    .mean()
    .mul(100)
    .unstack()
)

sns.heatmap(pivot_user, annot=True, cmap="coolwarm", fmt=".1f")
plt.title("User-Level Weaponisation Rate\n(User Type × Account Age)")
plt.ylabel("User Type")
plt.xlabel("Account Age (Quantile Bins)")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_88627/3547387567.py:59: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["user_type", "age_bin"])["weaponised_rate"]

# %%
df_enriched["date"] = pd.to_datetime(df_enriched["date"], utc=True, errors="coerce")
df_enriched["registration"] = pd.to_datetime(df_enriched["registration"], utc=True, errors="coerce")

df_enriched["account_age_days"] = (df_enriched["date"] - df_enriched["registration"]).dt.total_seconds() / 86400
df_enriched["account_age_years"] = df_enriched["account_age_days"] / 365.25

plt.figure(figsize=(12, 6))
sns.histplot(
    data=df_enriched.dropna(subset=["account_age_years"]),
    x="account_age_years",
    hue="weaponised",
    bins=10,
    kde=True,
    stat="density",
    common_norm=False
)
plt.title("Account Age Distribution at Time of Edit\n(Weaponised vs Non-Weaponised)")
plt.xlabel("Account Age (years)")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Editcount

# %%
(
    df_enriched[df_enriched["user_type"] == "Registered"]
    .assign(
        weaponised_binary=lambda d: d["weaponised"].eq("Weaponised").astype(int),
        editcount_bin=lambda d: pd.qcut(d["editcount"], q=10, duplicates="drop")
    )
    .groupby("editcount_bin")["weaponised_binary"]
    .mean()
    .mul(100)
    .plot.bar(
        figsize=(12, 5),
        title="Weaponisation Rate vs Editcount (Registered Users Only)",
        ylabel="Weaponised Edits (%)",
        rot=45
    )
)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_88627/548309439.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("editcount_bin")["weaponised_binary"]

# %% [markdown]
# ## Account age and editcount

# %%
df_enriched_age = compute_account_age(df_enriched)

df_reg = df_enriched_age[df_enriched_age["user_type"] == "Registered"].copy()

df_reg["weaponised_binary"] = df_reg["weaponised"].eq("Weaponised").astype(int)

df_reg["account_age_years"] = df_reg["account_age_days"] // 365

df_reg["editcount_bin"] = pd.qcut(df_reg["editcount"], q=6, duplicates="drop")
df_reg["age_bin"] = pd.qcut(df_reg["account_age_years"], q=6, duplicates="drop")

pivot = (
    df_reg
    .groupby(["age_bin", "editcount_bin"])["weaponised_binary"]
    .mean()
    .mul(100)
    .unstack()
)

plt.figure(figsize=(12, 6))
sns.heatmap(
    pivot,
    cmap="coolwarm",
    annot=True,
    fmt=".1f",
    cbar_kws={"label": "Weaponised Edits (%)"}
)

plt.title("Weaponisation Rate by Account Age and Edit Count\n(Registered Users)")
plt.xlabel("Edit Count (Quantile Bins)")
plt.ylabel("Account Age (Quantile Bins)")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/t4/w6j9k5hs52b5jx9px2689lzc0000gn/T/ipykernel_88627/905664244.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["age_bin", "editcount_bin"])["weaponised_binary"]

# %% [markdown]
# ## Groups

# %%
import ast

def parse_groups(val):
    if pd.isna(val):
        return []
    try:
        # Ensure it's list-like
        return [g.strip() for g in ast.literal_eval(val)]
    except Exception:
        # Fallback if malformed
        return []

df_enriched["groups"] = df_enriched["groups"].apply(parse_groups)

all_groups = [
    g
    for groups in df_enriched["groups"]
    for g in groups
]

unique_groups = sorted(set(all_groups))

print(f"Number of unique rights: {len(unique_groups)}")
for g in unique_groups:
    print("-", g)

df_enriched["groups"] = df_enriched["groups"].apply(
    lambda g: [x for x in g if x != "*"]
)
# Out:
# Number of unique rights: 25
# - *
# - abusefilter
# - abusefilter-helper
# - accountcreator
# - autoconfirmed
# - autoreviewer
# - bureaucrat
# - checkuser
# - electionclerk
# - eventcoordinator
# - extendedconfirmed
# - extendedmover
# - filemover
# - import
# - interface-admin
# - ipblock-exempt
# - massmessage-sender
# - patroller
# - reviewer
# - rollbacker
# - suppress
# - sysop
# - templateeditor
# - temporary-account-viewer
# - user

# %%
df_groups = df_enriched.explode("groups")
df_groups = df_groups[df_groups["groups"] != ""]

# %%
(
    df_groups
    .groupby("groups")["weaponised"]
    .apply(lambda s: (s == "Weaponised").mean() * 100)
    .sort_values(ascending=False)
    .plot.bar(figsize=(12,5))
)
plt.ylabel("Weaponised Edits (%)")
plt.title("Weaponisation Rate by User Rights")
plt.tight_layout()
plt.show()
