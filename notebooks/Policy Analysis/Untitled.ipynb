# %% [markdown]
# # Plots and Graphs from Policy Analysis

# %% [markdown]
# ## Requirements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.patches import Patch
import re
import requests
import time
from datetime import datetime
from datetime import timezone
import csv
import mwparserfromhell
import sys

# %%
df = pd.read_csv('../../datas/final/all_users_analysis_final.csv')
articles = sorted(df['article'].unique().tolist())
df_policy = pd.read_csv('../../datas/interim/Policy Analysis/policy_analysis_articles.csv')
df_control = pd.read_csv('../../datas/interim/Policy Analysis/policy_analysis_control_articles.csv')

# %%
df_policy
# Out:
#                                               article  class importance  \
# 0                        COVID-19 pandemic in Ukraine  Start        low
# 1                                  History of Ukraine      B        top
# 2                                              Crimea      C        top
# 3                        Russian annexation of Crimea      B        top
# 4                2004 Ukrainian presidential election      C       high
# 5                                 Football in Ukraine  Start        mid
# 6                                          Bessarabia      B       high
# 7                  2014 pro-Russian unrest in Ukraine      C       high
# 8                 Communist Party of the Soviet Union      C        top
# 9                              Christianity in Russia      C       high
# 10                 History of Christianity in Ukraine      B       high
# 11                                    Flag of Ukraine      C        top
# ...
