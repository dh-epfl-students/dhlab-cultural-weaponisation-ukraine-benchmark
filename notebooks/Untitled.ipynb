# %%
import pandas as pd
import sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 import sql
#
# ModuleNotFoundError: No module named 'sql'

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("temp.db")

# Load the .sql dump into SQLite
with open("/Users/garambois/Downloads/enwiki-20251101-babel.sql", "r") as f:
    sql_script = f.read()
conn.executescript(sql_script)

# Now you can read the table
df = pd.read_sql("SELECT * FROM babel", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 9
#       7 with open("/Users/garambois/Downloads/enwiki-20251101-babel.sql", "r") as f:
#       8     sql_script = f.read()
# ----> 9 conn.executescript(sql_script)
#      11 # Now you can read the table
#      12 df = pd.read_sql("SELECT * FROM babel", conn)
#
# OperationalError: near "unsigned": syntax error
