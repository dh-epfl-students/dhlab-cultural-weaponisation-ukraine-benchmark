# %% [markdown]
# # Analysis of Weaponised Wikipedia Edits
#
# ## Data Import and Structure
#
# From the **LLM Results** folder, I retrieved every `.csv` file and stored them in a list called `dfs`.
#
# I also created a dictionary `dfs_named` that maps each article name to its corresponding CSV table containing all edits for that article:
#
# ```python
# dfs_named["2004_Ukrainian_presidential_election_analysis"]
# dfs_named["Abortion_in_Ukraine_analysis"]
# ```
# * `dfs` contains 120 CSV tables, giving 117,517 rows.
#
# ## Filtering for Weaponised Edits
#
# From these 117,517 rows, I only kept the ones classified as Weaponised by the LLM:
# ```python
# dfs_weaponised = [df[df['weaponised'] == 'Weaponised'] for df in dfs]
# ```
#
# This reduces the dataset to **18,707 rows**, i.e., 18,707 edits potentially considered weaponised.
#
# Each DataFrame in `dfs_weaponised` contains exactly 7 columns:
#
# * initial_version – text before the edit
# * changed_version – text after the edit
# * comment – user’s comment explaining the edit
# * user – username of the editor
# * date – timestamp of the edit (ISO format)
# * llm_output – LLM evaluation of the edit
# * weaponised – classification: `"Weaponised"` (because `"Not weaponised"` has already been filtered out).
#
# I also created another dictionary, `dfs_weaponised_named`, to keep track of article names alongside their corresponding filtered DataFrames.
#
# ## Mapping External Chunks to Wikipedia Edits
#
# The goal is to check whether externally provided text chunks appear in the weaponised edits.
# To do this, I implemented a function:
#
# ```python
# def generate_ngrams(text, n=4):
#     words = text.split()
#     return [" ".join(words[i:i+n]) for i in range(len(words)-n+1)]
# ```
#
# This function slices a text into overlapping sequences of n consecutive words (n-grams).
# I then looped over all weaponised DataFrames and checked if any n-gram was present in the **changed_version** column.
#
# ### Example
#
# Consider the following chunk:
#
# ```bash
# "A referendum in the largely ethnic Russian Ukrainian autonomous region of Crimea resulted in the bloodless annexation of Crimea by Russia on 18 March 2014."
# ```
#
# Its 4-word n-grams include:
#
# ```python
# 'A referendum in the',
#  'the largely ethnic Russian',
#  'Russian Ukrainian autonomous region',
#  'region of Crimea resulted',
#  'resulted in the bloodless',
#  'bloodless annexation of Crimea',
#  'Crimea by Russia on',
#  'on 18 March 2014.']
# ```
#
# When searching with the slice "bloodless annexation of Crimea", the following matches were found:
#
# ```
# Match found in article 'History_of_Ukraine_analysis', rows [384, 389]
# Match found in article 'History_of_Ukraine#Early_modern_period_analysis', rows [391, 394]
# Match found in article 'History_of_Ukraine#World_War_II_and_the_Nazi_Occupation_analysis', rows [381, 390]
# ```
#
# ## Manual Verification
#
# I manually checked one example:
#
# ```python
# dfs_weaponised_named["History_of_Ukraine#Early_modern_period_analysis"].loc[391, "changed_version"]
# ```
# The output confirmed that the **changed_version** at that row contained the phrase *"bloodless annexation of Crimea"*.

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Path to the folder containing CSVs or .xlsx
csv_folder = Path("datas/previous-project/Hedi/LLM Results")

# Create a list of DataFrames, one for each CSV
dfs = [pd.read_csv(f) for f in csv_folder.glob("*.csv")]

dfs_named = {f.stem: pd.read_csv(f) for f in csv_folder.glob("*.csv")}

# Example: show how many DataFrames were loaded
print(f"Loaded {len(dfs)} CSV files.")
print("Available keys:", list(dfs_named.keys()))
# Out:
# Loaded 120 CSV files.
# Available keys: ['COVID-19_pandemic_in_Ukraine_analysis', 'Immigration_to_Ukraine_analysis', 'Andrei_Sheptytsky_analysis', 'Football_in_Ukraine_analysis', 'Abortion_in_Ukraine_analysis', '2004_Ukrainian_presidential_election_analysis', 'History_of_Ukraine_analysis', 'Christianity_in_Russia_analysis', 'Cossack’s_songs_of_Dnipropetrovsk_Region_analysis', 'Flag_of_Ukraine_analysis', 'Belarusians_in_Ukraine_analysis', 'Cinema_of_Ukraine_analysis', 'Brotherhood_of_Independent_Baptist_Churches_and_Ministries_of_Ukraine_analysis', 'Hillsong_Ukraine_analysis', 'Communist_Party_of_the_Soviet_Union_analysis', 'Electricity_in_Ukraine_analysis', 'Censuses_in_Ukraine_analysis', 'Declaration_of_Independence_of_Ukraine_analysis', 'History_of_Christianity_in_Ukraine_analysis', 'Bessarabia_analysis', 'Human_trafficking_in_Ukraine_analysis', 'Crimea_analysis', 'Epiphanius_I_of_Ukraine_analysis', 'Hillsong_Church_Kiev_analysis', 'Government_of_the_Ukrainian_People_s_Republic_in_exile_analysis', 'Directorate_of_Ukraine_analysis', 'Evangelical_Presbyterian_Church_of_Ukraine_analysis', 'Eastern_Front_(World_War_II)_analysis', 'English_Civil_War_analysis', 'Galicia_(Central_Europe)_analysis', 'Hunnic_Invasion_analysis', 'History_of_Crimea_analysis', 'Crimean_Tatars_analysis', 'Buddhism_in_Ukraine_analysis', 'Alexander_II_of_Russia_analysis', 'Christianity_in_Ukraine_analysis', 'History_of_jewellery_in_Ukraine_analysis', 'Crimean_peninsula_analysis', 'Encyclopedia_of_Ukraine_analysis', 'Granting_of_autocephaly_to_the_Orthodox_Church_of_Ukraine_analysis', 'Armed_Forces_of_Ukraine_analysis', 'History_of_Ukraine#Early_modern_period_analysis', 'Crimean_Tatar_literature_analysis', 'Communist_Party_of_Ukraine_(Soviet_Union)_analysis', 'History_of_television_in_Ukraine_analysis', 'Bibliography_of_Ukrainian_history_analysis', 'Folklore_of_Ukraine_analysis', 'Government_of_Ukraine_analysis', 'History_of_the_Cossacks_analysis', 'Banking_in_Ukraine_analysis', 'Culture_of_Ukraine_analysis', 'Christmas_in_Ukraine_analysis', 'Bahá_í_Faith_in_Ukraine_analysis', 'Economic_history_of_Ukraine_analysis', 'Cossack_Hetmanate_analysis', 'Evangelical_Lutheran_Church_in_Russia,_Ukraine,_Kazakhstan_and_Central_Asia_analysis', 'Demographics_of_Ukraine_analysis', 'Carpathian_Ruthenia_analysis', 'Foreign_relations_of_Ukraine_analysis', 'Economy_of_Ukraine_analysis', '2014_pro-Russian_unrest_in_Ukraine_analysis', 'Christmas_Eve#Ukraine_analysis', 'Crime_in_Ukraine_analysis', 'History_of_rail_transport_in_Ukraine_analysis', 'Administrative_divisions_of_Ukraine_analysis', 'History_of_Ukraine#World_War_II_and_the_Nazi_Occupation_analysis', 'Andrey_Kurkov_analysis', 'History_of_Kyiv_analysis', 'Dissolution_of_the_Soviet_Union_analysis', 'Energy_in_Ukraine_analysis', 'History_of_the_Soviet_Union_(1985-1991)_analysis', 'HIV_AIDS_in_Ukraine_analysis', 'Art_of_Ukraine_analysis', 'Corruption_in_Ukraine_analysis', 'Constitution_of_Ukraine_analysis', '2022_Russian_invasion_of_Ukraine_analysis', 'Arts_of_Ukraine_analysis', 'Hinduism_in_Ukraine_analysis', 'Architecture_of_Ukraine_analysis', 'Bulgarians_in_Ukraine_analysis', 'Baptism_of_Kiev_analysis', 'Education_in_Ukraine_analysis', 'Health_in_Ukraine_analysis', 'Baptists_in_Ukraine_analysis', 'Eastern_Front_(World_War_I)_analysis', 'Dnieper_Cossacks_analysis', 'Culture_of_Russia_analysis', 'Andriy_Shevchenko_analysis', 'History_of_shipbuilding_in_Ukraine_analysis', 'Architecture_of_Kievan_Rus__analysis', 'Elections_in_Ukraine_analysis', 'Armenian_Diocese_of_Ukraine_analysis', 'Galicia_(Eastern_Europe)_analysis', 'All-Ukrainian_Union_of_Churches_of_Evangelical_Christian_Baptists_analysis', 'Coat_of_arms_of_Ukraine_analysis', 'Dorus_(Crimea)_analysis', 'Imperial_Russian_Army_analysis', 'Crimean_Tatar_language_analysis', 'History_of_the_Russian_Orthodox_Church_analysis', 'FC_Dynamo_Kyiv_analysis', 'History_of_the_Jews_in_Ukraine_analysis', 'History_of_banking_in_Ukraine_analysis', 'Freedom_of_the_press_in_Ukraine_analysis', 'Ethnic_groups_i ...

# %%
# dfs_weaponised is a list of the dataframes with only edits that were classified as weaponised by the LLM
dfs_weaponised = [df[df['weaponised'] == 'Weaponised'].reset_index(drop=True) for df in dfs]
print(len(dfs_weaponised))
# Out:
# 120

# %%
best_chunks = pd.read_excel("datas/previous-project/Hedi/best_chunks_semi_automated_annotated_data_repaired.xlsx")

# %%
best_chunks = best_chunks[best_chunks['Annot 1'].fillna('') == 'Correct']
best_chunks = best_chunks[best_chunks['Annot 2'].fillna('') == 'Correct']
best_chunks = best_chunks[best_chunks['Annot 1 - new'].fillna('') == 'Correct']
best_chunks = best_chunks[best_chunks['Annot 2 - new'].fillna('') == 'Correct']

# %%
best_chunks.iloc[10:20]
# Out:
#     row_index                                    detected_before  \
# 34        132  The '''Ukrainian Orthodox Church''' is an auto...
# 36        151  The '''[[Ukraine|Ukrainian]] revolution''' of ...
# 37        154  In so far as he had any decided political conv...
# 39        159  The '''English Civil War''' consisted of a ser...
# 41        165  Kutia (sweet grain pudding) is traditionally s...
# 42        173  Yanukovych fled Ukraine amid the [[Euromaidan]...
# 44        183  In late February 2014, Russia began to send tr...
# 47        200  [[Image:Kraina_Mriy_Ukraine_folk_costume_flowe...
# 50        219  After the [[Soviet invasion]]{{dn|date=Februar...
# 58        252  In accordance with that time's Imerial termino...
#
#                                        detected_after  \
# 34  --- \n+++ \n@@ -3,7 +3,7 @@\n | icon          ...
# 36  The '''NATO Coup of 2014''' (never known as th...
# 37  Insofar as he may have had political syphilis ...
# 39  The '''English Civil War''' consisted of a ser...
# 41  Kutta (sweet grain pudding) is traditionally s...
# 42  Yanukovych fled Ukraine amid the [[Euromaidan]...
# 44  In late February 2014, black american chimpanz...
# 47  --- \n+++ \n@@ -2,15 +2,15 @@\n The '''Ukraini...
# 50  After the [[Soviet invasion]]{{disambiguation ...
# 58  In accordance with that time's prevailing term...
#
#                                          clean_before  \
# 34  The '''Ukrainian Orthodox Church''' is an auto...
# 36  The '''Ukrainian revolution''' of February 201...
# 37  In so far as he had any decided political conv...
# 39  The '''English Civil War''' consisted of a ser...
# 41  Kutia (sweet grain pudding) is traditionally s...
# 42  Yanukovych fled Ukraine amid the Euromaidan up...
# 44  In late February 2014, Russia began to send tr...
# 47  thumb|A girl wearing a Ukrainian costume with ...
# 50  After the Soviet invasion of Ukraine in 1920 a...
# 58  In accordance with that time's Imerial termino...
#
#                                           clean_after  \
# 34  --- \n+++ \n@@ -3,7 +3,7 @@\n | icon          ...
# 36  The '''NATO Coup of 2014''' (never known as th...
# 37  Insofar as he may have had political syphilis ...
# 39  The '''English Civil War''' consisted of a ser...
# 41  Kutta (sweet grain pudding) is traditionally s...
# 42  Yanukovych fled Ukraine amid the Euromaidan co...
# 44  In late February 2014, black american chimpanz...
# 47  --- \n+++ \n@@ -2,15 +2,15 @@\n The '''Ukraini...
# 50  After the Soviet invasion of Ukraine in 1920 a...
# 58  In accordance with that time's prevailing term...
#
#                           type_of_change_extracted  category_extracted_clean  \
# 34                         rephrasing and renaming  Terminology Manipulation
# 36                                    synonym swap  Terminology Manipulation
# 37                                      rephrasing  Terminology Manipulation
# 39                 word replacement and rephrasing  Terminology Manipulation
# 41  Terminology manipulation and phrase alteration  Terminology Manipulation
# 42                                    synonym swap  Terminology Manipulation
# 44                         replacement of a phrase  Terminology Manipulation
# 47                                    synonym swap  Terminology Manipulation
# 50                               Formatting change  Terminology Manipulation
# 58                                    synonym swap  Terminology Manipulation
#
#     propaganda_similarity category_extracted_propaganda_mapped  \
# 34               0.418396   Obfuscation, intentional vagueness
# 36               0.418396   Obfuscation, intentional vagueness
# 37               0.418396   Obfuscation, intentional vagueness
# 39               0.418396   Obfuscation, intentional vagueness
# 41               0.418396   Obfuscation, intentional vagueness
# 42               0.418396   Obfuscation, intentional vagueness
# 44               0.418396   Obfuscation, intentional vagueness
# 47               0.418396   Obfuscation, intentional vagueness
# 50               0.418396   Obfuscation, intentional vagueness
# 58               0.418396   Obfuscation, intentional vagueness
#
#                                  aligned_before_chunk  \
# 34  The '''Ukrainian Orthodox Church''' is an auto...
# 36  The '''Ukrainian revolution''' of February 201...
# 37  In so far as he had any decided political conv...
# 39  The '''English Civil War''' consisted of a ser...
# 41  Kutia (sweet grain pudding) is traditionally s...
# 42  Yanukovych fled Ukraine amid the Euromaidan up...
# 44  In late February 2014, Russia began to send tr...
# 47  \nThe flowers used to make the vinok were gene...
# 50  After the Soviet invasion of Ukraine in 1920 a...
# 58  In accordance with that time's Imerial termino...
#
#                                   aligned_after_chunk  similarity  \
# 34   The '''Ukrainian Orthodox Church''' ('''UOC''...    0.913820
# 36  The '''NATO Coup of 2014''' (never known as th...    0.898157
# 37  Insofar as he may have had political syphilis ...    0.577801
# 39  The '''English Civil War''' consisted of a ser...    0.877601
# 41  Kutta (sweet grain pudding) is traditionally s...    0.857476
# 42  Yanukovych fled Ukraine amid the Euromaidan co...    0.973109
# 44  In late February 2014, black american chimpanz...    0.692616
# 47  \n The flowers used to make the ''vinok'' were...    0.989811
# 50  After the Soviet invasion of Ukraine in 1920 a...    1.000000
# 58  In accordance with that time's prevailing term...    0.933020
#
#                                significance_extracted  Annot 1  Annot 2  \
# 34  The change from 'Ukrainian Orthodox Church' to...  Correct  Correct
# 36  This change alters the historical narrative by...  Correct  Correct
# 37  This edit introduces vulgar and derogatory lan...  Correct  Correct
# 39  The changes introduce derogatory and sexualize...  Correct  Correct
# 41  The change from 'Kutia' to 'Kutta' may dilute ...  Correct  Correct
# 42  The change from 'uprising' to 'coup' alters th...  Correct  Correct
# 44  This change introduces a racially charged and ...  Correct  Correct
# 47  The replacement of 'vinok' with 'wreath' dimin...  Correct  Correct
# 50  The change from 'dn' to 'disambiguation needed...  Correct  Correct
# 58  The change from 'Imperial terminology' to 'pre...  Correct  Correct
#
#    Annot 1 - new Annot 2 - new Column 1
# 34       Correct       Correct    Agree
# 36       Correct       Correct    Agree
# 37       Correct       Correct    Agree
# 39       Correct       Correct    Agree
# 41       Correct       Correct    Agree
# 42       Correct       Correct    Agree
# 44       Correct       Correct    Agree
# 47       Correct       Correct    Agree
# 50       Correct       Correct    Agree
# 58       Correct       Correct    Agree

# %%
dfs_weaponised = [df for df in dfs_weaponised if not df.empty]
dfs_weaponised_named = {
    name: df[df['weaponised'] == 'Weaponised'].reset_index(drop=True)
    for name, df in dfs_named.items()
    if not df[df['weaponised'] == 'Weaponised'].empty
}
