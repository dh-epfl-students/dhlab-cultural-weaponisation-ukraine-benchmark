# %% [markdown]
# # Preprocessing of the Small Database (6,922 edits)
#
# This notebook documents the **preprocessing pipeline and methodological choices** used to clean and normalise the raw dataset obtained from the edit–article matching process.
# The objective of this step is to transform heterogeneous, noisy Wikipedia data into a **consistent and analytically reliable dataset**, suitable for downstream exploration, statistical analysis, and modelling.
#
# The preprocessing relies on a single, reusable function applied uniformly to the entire dataset, ensuring **reproducibility and transparency**.
#
# ---
#
# ## Preprocessing Function Overview
#
# The function below defines the complete cleaning and normalisation pipeline applied to the raw dataframe:
#
# - temporal harmonisation,
# - article name standardisation,
# - weaponisation label normalisation,
# - user-type inference,
# - and column selection.
#
# ## Detailed Preprocessing Steps
#
# ### 1. Temporal Normalisation and Deduplication
#
# - A `year` column is created from the edit timestamp to enable **yearly distribution analyses**.
# - Duplicate edits are removed based on the `(article, date)` pair to avoid double counting.
#
# This ensures temporal coherence and prevents artefacts due to duplicated records.
#
#
# ### 2. Article Title Cleaning and Normalisation
#
# - Technical suffixes (e.g. `_analysis`) are removed.
# - Underscores are replaced by spaces to match Wikipedia’s canonical naming conventions.
# - Known article title changes are manually harmonised to ensure consistency across time.
#
# This step is essential to avoid **artificial article fragmentation** in the analysis.
#
#
# ### 3. Weaponisation Label Harmonisation
#
# - The `weaponised` field is normalised by:
#   - lowercasing,
#   - trimming whitespace,
#   - and mapping heterogeneous labels to a controlled vocabulary:
#     - `Weaponised`
#     - `Not Weaponised`
#     - `Unknown`
# - Entries labelled as `Unknown` are excluded from further analysis to preserve interpretability.
#
# This guarantees **semantic consistency** across analyses involving weaponisation.
#
#
# ### 4. User Type Inference
#
# User types are inferred directly from the `user` field using heuristic rules:
#
# - **Anonymous (IP)**
#   Detected via IPv4 / IPv6 regular expression matching.
# - **Bot**
#   Detected via case-insensitive matching of the string `"bot"` in the username.
# - **Registered**
#   Default category when neither anonymous nor bot conditions apply.
#
# This classification allows systematic comparison of **editorial behaviour across user categories**.
#
#
# ### 5. Column Pruning and Dataset Simplification
#
# - Intermediate columns used for inference (`is_anon`, `is_bot`) are removed.
# - Non-essential or redundant columns inherited from the raw extraction are dropped.
#
# The resulting dataframe retains only variables relevant to:
# - editorial behaviour,
# - user categorisation,
# - temporal analysis,
# - and weaponisation status.
#
# ---
#
# ## Output
#
# The output of the preprocessing function is a **cleaned, standardised dataframe** that:
# - is free of duplicates,
# - uses consistent article and label naming,
# - contains an explicit `user_type` variable,
# - and is ready for exploratory analysis and modelling.
#
#
# ## Research Objective
#
# This preprocessing step lays the foundation for all subsequent analyses.
# By enforcing strict data hygiene and explicit methodological choices, it ensures that any detected patterns — including **signals of weaponisation or coordinated behaviour** — are attributable to genuine editorial dynamics rather than artefacts of data collection or formatting.
#
# The resulting dataset is designed to support feature extraction for the development of a downstream **Large Language Model (LLM)** focused on identifying and contextualising manipulative or strategic editing behaviours on Wikipedia.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import calendar
from tqdm import tqdm

# %%
df = pd.read_csv('../../datas/interim/Small Database Analysis/matched_edits_all.csv')

# %%
df
# Out:
#                                           article                 user  \
# 0           COVID-19_pandemic_in_Ukraine_analysis           Agathoclea
# 1                     History_of_Ukraine_analysis                 Icey
# 2                     History_of_Ukraine_analysis                Irpen
# 3                     History_of_Ukraine_analysis       193.60.161.100
# 4                     History_of_Ukraine_analysis                Irpen
# ...                                           ...                  ...
# 6917        COVID-19_pandemic_in_Ukraine_analysis                 LSGH
# 6918  2014_pro-Russian_unrest_in_Ukraine_analysis             Garik 11
# 6919  2014_pro-Russian_unrest_in_Ukraine_analysis  Aleksandr Grigoryev
# 6920                 Censuses_in_Ukraine_analysis  Aleksandr Grigoryev
# 6921                 Censuses_in_Ukraine_analysis  AdventurousSquirrel
#
#                       date                                            comment  \
# 0     2020-03-11T20:56:06Z  removed [[Category:2019–20 coronavirus outbrea...
# 1     2006-05-21T14:09:22Z  /* Further reading */ Disambiguation link repa...
# 2     2006-06-06T21:00:08Z  this whole section doesn't belong here, speara...
# 3     2006-05-23T11:39:26Z                                                NaN
# 4     2006-06-14T17:49:44Z                                   revert to myself
# ...                    ...                                                ...
# 6917  2021-05-06T05:57:13Z                Updating number of cases in infobox
# 6918  2014-04-08T17:05:13Z  /* Latvian citizen arrested */ more detail abo...
# 6919  2014-04-19T15:24:13Z     /* Kidnapping of Ukrainian officials */ update
# 6920  2012-11-17T17:14:35Z                        /* External links */ update
# 6921  2013-06-09T00:44:29Z  Disambiguated: [[Soviet Census]] → [[Soviet Ce...
#
#                                              llm_output      weaponised  \
# 0     Changed the category from "2019–20 coronavirus...  Not Weaponised
# 1     Changed the reference format for Andrew Wilson...  Not Weaponised
# 2     Removed a section titled "Ukraine and Nuclear ...  Not Weaponised
# 3     Changed "beyond" to "gayniss" in the context o...  Not Weaponised
# 4     Removed a POV (point of view) section regardin...  Not Weaponised
# ...                                                 ...             ...
# 6917  Changed confirmed cases, recovery cases, death...  Not Weaponised
# 6918  Changed the description of a Latvian citizen b...  Not Weaponised
# 6919  The change made in this revision is the additi...      Weaponised
# 6920  Added a template for "Ukraine topics" and a ca...  Not Weaponised
# 6921  Change: Replaced the link from [[Soviet Census...  Not Weaponised
#
#                              ngram  df_index  row_index_matched  fg_row_index  \
# 0          annexation of Crimea by         0                 15             6
# 1              A referendum in the         4                384             6
# 2              A referendum in the         4                389             6
# 3            in the largely ethnic         4                383             6
# 4            in the largely ethnic         4                392             6
# ...                            ...       ...                ...           ...
# 6917   Donetsk and Luhansk oblasts        46               1180           798
# 6918        and Luhansk oblasts of        46                672           798
# 6919  together commonly called the        46               1173           798
# 6920             took place in the        58                  5           798
# 6921             took place in the        58                  6           798
#
#       ...                                       clean_before  \
# 0     ...  A referendum in the largely ethnic Russian Ukr...
# 1     ...  A referendum in the largely ethnic Russian Ukr...
# 2     ...  A referendum in the largely ethnic Russian Ukr...
# 3     ...  A referendum in the largely ethnic Russian Ukr...
# 4     ...  A referendum in the largely ethnic Russian Ukr...
# ...   ...                                                ...
# 6917  ...  On 26 February 2014, Russian-speaking gunmen s...
# 6918  ...  On 26 February 2014, Russian-speaking gunmen s...
# 6919  ...  On 26 February 2014, Russian-speaking gunmen s...
# 6920  ...  On 26 February 2014, Russian-speaking gunmen s...
# 6921  ...  On 26 February 2014, Russian-speaking gunmen s...
#
#                                             clean_after  \
# 0     A referendum in the largely ethnic Russian Ukr...
# 1     A referendum in the largely ethnic Russian Ukr...
# 2     A referendum in the largely ethnic Russian Ukr...
# 3     A referendum in the largely ethnic Russian Ukr...
# 4     A referendum in the largely ethnic Russian Ukr...
# ...                                                 ...
# 6917  --- \n+++ \n@@ -78,7 +78,7 @@\n \n \n \n-In la...
# 6918  --- \n+++ \n@@ -78,7 +78,7 @@\n \n \n \n-In la...
# 6919  --- \n+++ \n@@ -78,7 +78,7 @@\n \n \n \n-In la...
# 6920  --- \n+++ \n@@ -78,7 +78,7 @@\n \n \n \n-In la...
# 6921  --- \n+++ \n@@ -78,7 +78,7 @@\n \n \n \n-In la...
#
#                           type_of_change_extracted  category_extracted_clean  \
# 0     rephrasing and addition of descriptive terms  Terminology Manipulation
# 1     rephrasing and addition of descriptive terms  Terminology Manipulation
# 2     rephrasing and addition of descriptive terms  Terminology Manipulation
# 3     rephrasing and addition of descriptive terms  Terminology Manipulation
# 4     rephrasing and addition of descriptive terms  Terminology Manipulation
# ...                                            ...                       ...
# 6917                            addition of phrase  Terminology Manipulation
# 6918                            addition of phrase  Terminology Manipulation
# 6919                            addition of phrase  Terminology Manipulation
# 6920                            addition of phrase  Terminology Manipulation
# 6921                            addition of phrase  Terminology Manipulation
#
#      propaganda_similarity category_extracted_propaganda_mapped  \
# 0                 0.418396   Obfuscation, intentional vagueness
# 1                 0.418396   Obfuscation, intentional vagueness
# 2                 0.418396   Obfuscation, intentional vagueness
# 3                 0.418396   Obfuscation, intentional vagueness
# 4                 0.418396   Obfuscation, intentional vagueness
# ...                    ...                                  ...
# 6917              0.418396   Obfuscation, intentional vagueness
# 6918              0.418396   Obfuscation, intentional vagueness
# 6919              0.418396   Obfuscation, intentional vagueness
# 6920              0.418396   Obfuscation, intentional vagueness
# 6921              0.418396   Obfuscation, intentional vagueness
#
#                                    aligned_before_chunk  \
# 0     A referendum in the largely ethnic Russian Ukr...
# 1     A referendum in the largely ethnic Russian Ukr...
# 2     A referendum in the largely ethnic Russian Ukr...
# 3     A referendum in the largely ethnic Russian Ukr...
# 4     A referendum in the largely ethnic Russian Ukr...
# ...                                                 ...
# 6917  On 26 February 2014, Russian-speaking gunmen s...
# 6918  On 26 February 2014, Russian-speaking gunmen s...
# 6919  On 26 February 2014, Russian-speaking gunmen s...
# 6920  On 26 February 2014, Russian-speaking gunmen s...
# 6921  On 26 February 2014, Russian-speaking gunmen s...
#
#                                     aligned_after_chunk similarity  \
# 0     A referendum in the largely ethnic Russian Ukr...   0.925267
# 1     A referendum in the largely ethnic Russian Ukr...   0.925267
# 2     A referendum in the largely ethnic Russian Ukr...   0.925267
# 3     A referendum in the largely ethnic Russian Ukr...   0.925267
# 4     A referendum in the largely ethnic Russian Ukr...   0.925267
# ...                                                 ...        ...
# 6917  \n \n During the Crimean crisis, demonstration...   0.562791
# 6918  \n \n During the Crimean crisis, demonstration...   0.562791
# 6919  \n \n During the Crimean crisis, demonstration...   0.562791
# 6920  \n \n During the Crimean crisis, demonstration...   0.562791
# 6921  \n \n During the Crimean crisis, demonstration...   0.562791
#
#                                  significance_extracted
# 0     The use of terms like 'bloodless' and 'bloody ...
# 1     The use of terms like 'bloodless' and 'bloody ...
# 2     The use of terms like 'bloodless' and 'bloody ...
# 3     The use of terms like 'bloodless' and 'bloody ...
# 4     The use of terms like 'bloodless' and 'bloody ...
# ...                                                 ...
# 6917  The addition of the phrase 'in what has been t...
# 6918  The addition of the phrase 'in what has been t...
# 6919  The addition of the phrase 'in what has been t...
# 6920  The addition of the phrase 'in what has been t...
# 6921  The addition of the phrase 'in what has been t...
#
# [6922 rows x 22 columns]

# %%
def preprocess(dataframe):
    df = dataframe.copy()
    
    # Apply a year column in order to see a yearly distribution of edits
    df["year"] = pd.to_datetime(df["date"], errors="coerce").dt.year
    df.drop_duplicates(subset=['article', 'date'], inplace=True)
    
    # clean the article column name
    df['article'] = (
        df['article']
        .str.replace('_analysis', '', regex=False)
        .str.replace('_', ' ', regex=False)
    )
    
    # updates new wikipedia article name
    df["article"] = df["article"].replace(
        "Annexation of Crimea by the Russian Federation",
        "2014 Russian annexation of Crimea"
    )

    df["article"] = df["article"].replace(
        'Government of the Ukrainian People s Republic in exile',
        "Government of the Ukrainian People's Republic in exile"
    )
    
    # Normalizing the weaponised field because there are some capitalised and soem not --> lowercase and strip
    df["weaponised"] = df["weaponised"].astype(str).str.strip().str.lower()
    df["weaponised"] = df["weaponised"].replace({
        "true": "Weaponised",
        "false": "Not Weaponised",
        "unknown": "Unknown",
        "weaponised": "Weaponised",
        "not weaponised": "Not Weaponised"
    })
    
    df = df[df["weaponised"] != "Unknown"]
    
    # easy way to detected IP address
    ipv4_ipv6_pattern = (
        r"^(?:\d{1,3}\.){3}\d{1,3}$|"  # IPv4
        r"^(?:[A-Fa-f0-9]{0,4}:){2,7}[A-Fa-f0-9]{0,4}$"  # IPv6
    )

    # find what type of user a name is
    df["is_anon"] = df["user"].str.contains(ipv4_ipv6_pattern, na=False)
    df['is_bot'] = df['user'].str.contains('bot', case=False, na=False)
    
    def get_user_type(row):
        if row["is_anon"]:
            return "Anonymous (IP)"
        elif row["is_bot"]:
            return "Bot"
        else:
            return "Registered"        
    
    df['user_type'] = df.apply(get_user_type, axis=1)
    
    # clean all the useless columns
    def drop_useless_columns(dataframe):
        df = dataframe.copy()
        df = df.drop(['is_anon', 'is_bot'], axis = 1)
        columns = df.columns.to_list()
        df = df.drop([c for c in columns[6:22]], axis = 1)
        return df

    df = drop_useless_columns(df)

    return df

# %%
# apply the preprocessing function to the raw dataset
df_preprocess = preprocess(df)
df_preprocess
# Out:
#                                  article                 user  \
# 0           COVID-19 pandemic in Ukraine           Agathoclea
# 1                     History of Ukraine                 Icey
# 2                     History of Ukraine                Irpen
# 3                     History of Ukraine       193.60.161.100
# 4                     History of Ukraine                Irpen
# ...                                  ...                  ...
# 6917        COVID-19 pandemic in Ukraine                 LSGH
# 6918  2014 pro-Russian unrest in Ukraine             Garik 11
# 6919  2014 pro-Russian unrest in Ukraine  Aleksandr Grigoryev
# 6920                 Censuses in Ukraine  Aleksandr Grigoryev
# 6921                 Censuses in Ukraine  AdventurousSquirrel
#
#                       date                                            comment  \
# 0     2020-03-11T20:56:06Z  removed [[Category:2019–20 coronavirus outbrea...
# 1     2006-05-21T14:09:22Z  /* Further reading */ Disambiguation link repa...
# 2     2006-06-06T21:00:08Z  this whole section doesn't belong here, speara...
# 3     2006-05-23T11:39:26Z                                                NaN
# 4     2006-06-14T17:49:44Z                                   revert to myself
# ...                    ...                                                ...
# 6917  2021-05-06T05:57:13Z                Updating number of cases in infobox
# 6918  2014-04-08T17:05:13Z  /* Latvian citizen arrested */ more detail abo...
# 6919  2014-04-19T15:24:13Z     /* Kidnapping of Ukrainian officials */ update
# 6920  2012-11-17T17:14:35Z                        /* External links */ update
# 6921  2013-06-09T00:44:29Z  Disambiguated: [[Soviet Census]] → [[Soviet Ce...
#
#                                              llm_output      weaponised  year  \
# 0     Changed the category from "2019–20 coronavirus...  Not Weaponised  2020
# 1     Changed the reference format for Andrew Wilson...  Not Weaponised  2006
# 2     Removed a section titled "Ukraine and Nuclear ...  Not Weaponised  2006
# 3     Changed "beyond" to "gayniss" in the context o...  Not Weaponised  2006
# 4     Removed a POV (point of view) section regardin...  Not Weaponised  2006
# ...                                                 ...             ...   ...
# 6917  Changed confirmed cases, recovery cases, death...  Not Weaponised  2021
# 6918  Changed the description of a Latvian citizen b...  Not Weaponised  2014
# 6919  The change made in this revision is the additi...      Weaponised  2014
# 6920  Added a template for "Ukraine topics" and a ca...  Not Weaponised  2012
# 6921  Change: Replaced the link from [[Soviet Census...  Not Weaponised  2013
#
#            user_type
# 0         Registered
# 1         Registered
# 2         Registered
# 3     Anonymous (IP)
# 4         Registered
# ...              ...
# 6917      Registered
# 6918      Registered
# 6919      Registered
# 6920      Registered
# 6921      Registered
#
# [6922 rows x 8 columns]

# %%
# store the preprocess database 
df_preprocess.to_csv('../../datas/final/small_db_preprocess.csv', index=False)
