# %%
import os 
import pandas as pd
import numpy as np


fg2 = pd.read_csv('finegrained_weaponisation2.csv')

fg2[fg2['category'].isna()]
# Out:
# Empty DataFrame
# Columns: [before, after, previous_output, type_of_change, category, significance, finegrain_output_raw]
# Index: []
