# %%
import os 
import pandas as pd
import numpy as np


fg1 = pd.read_csv('finegrained_weaponisation.csv')
fg2 = pd.read_csv('finegrained_weaponisation2.csv')
columns1 = fg1.columns
columns2 = fg2.columns
print(columns1)
# Out:
# Index(['before', 'after', 'previous_output', 'type_of_change', 'category',
#        'significance', 'finegrain_output_raw'],
#       dtype='object')

# %%
fg1.sample()
# Out:
#                                                 before  \
# 932  [[pl:Wiktor Juszczenko]]\n[[uk:&#1042;&#1110;&...
#
#                                                  after  \
# 932  --- \n+++ \n@@ -195,7 +195,7 @@\n \n Yushchenk...
#
#                                        previous_output  \
# 932  **Change Description:** Removed a reference to...
#
#               type_of_change            category  \
# 932  deletion and rephrasing  Selective Omission
#
#                                           significance  \
# 932  The edit selectively omits the condemnation of...
#
#                                   finegrain_output_raw
# 932  ```json\n{\n  "detected_changes": [\n    {\n  ...

# %%
value2 = fg2.iloc[932]["finegrain_output_raw"]
print(value2)
# Out:
# ```json
# {
#   "detected_changes": [
#     {
# ...
